# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import ast

# Carica CSV
fd = pd.read_csv('TrackFeatures4.csv')

# %%
def string_to_dict(fd, key):
    """Converte una stringa in un dizionario Python"""
    print(f"\nConverto le stringhe di '{key}' contenenti mean e std in dizionari Python")
    parsed = fd[key].apply(ast.literal_eval)
    mean = parsed.apply(lambda x: x['mean'])
    std = parsed.apply(lambda x: x['std'])
    return mean, std

# Appiattisci una matrice 2D in un vettore 1D
def flatten_feature_matrix(matrix):
    return np.array(matrix).flatten()
i=0
# Funzione per il preprocessing di una singola riga
def preprocess_row(row):
    global i
    print(f"\nPreprocessing riga {i}...")

    i+=1
    try:
        mfccs = ast.literal_eval(row['mfccs'])
        chroma = ast.literal_eval(row['chroma'])
        spec_contrast = ast.literal_eval(row['spec_contrast'])
        zcr = ast.literal_eval(row['zcr'])
        beats = ast.literal_eval(row['beats'])
        tempo_feature = float(row['tempo'].replace("[", "").replace("]", ""))

        mfccs_vec = np.concatenate([
            flatten_feature_matrix(mfccs['mean']),
            flatten_feature_matrix(mfccs['std'])
        ])

        chroma_vec = np.concatenate([
            flatten_feature_matrix(chroma['mean']),
            flatten_feature_matrix(chroma['std'])
        ])

        spec_vec = np.concatenate([
            flatten_feature_matrix(spec_contrast['mean']),
            flatten_feature_matrix(spec_contrast['std'])
        ])

        zcr_vec = np.concatenate([
            flatten_feature_matrix(zcr['mean']),
            flatten_feature_matrix(zcr['std'])
        ])

        beats_vec = np.array([beats['count'], beats['interval_mean'], beats['interval_std']])

        # Unisci tutte le feature in un vettore
        return np.concatenate([mfccs_vec, chroma_vec, spec_vec, zcr_vec, [tempo_feature], beats_vec])
    except Exception as e:
        print(row)
        print(f"Errore nel preprocessing della riga {i}: {e}")
        return np.zeros(5944)  # Restituisci un vettore di zeri della lunghezza corretta in caso di errore

# %%
# Funzione per convertire la stringa in dizionario
# Applichiamo il preprocessing a tutte le righe
print("Preprocessing in corso...")
feature_matrix = fd.apply(preprocess_row, axis=1)
X = np.stack(feature_matrix.to_numpy())  # Convertiamo in matrice numpy

# Label (target)
y = fd[fd.columns[1]]  # Etichetta dei generi musicali
print(f"\n\nMatrix X: {X.shape}")
# Out:
# Preprocessing in corso...
#
# Preprocessing riga 0...
#
# Preprocessing riga 1...
#
# Preprocessing riga 2...
#
# Preprocessing riga 3...
#
# Preprocessing riga 4...
#
# Preprocessing riga 5...
#
# Preprocessing riga 6...
#
# Preprocessing riga 7...
#
# Preprocessing riga 8...
#
# Preprocessing riga 9...
#
# Preprocessing riga 10...
#
# Preprocessing riga 11...
#
# Preprocessing riga 12...
#
# Preprocessing riga 13...
#
# Preprocessing riga 14...
#
# Preprocessing riga 15...
#
# Preprocessing riga 16...
#
# Preprocessing riga 17...
#
# Preprocessing riga 18...
#
# Preprocessing riga 19...
#
# Preprocessing riga 20...
#
# Preprocessing riga 21...
#
# Preprocessing riga 22...
#
# Preprocessing riga 23...
#
# Preprocessing riga 24...
#
# Preprocessing riga 25...
#
# Preprocessing riga 26...
#
# Preprocessing riga 27...
#
# Preprocessing riga 28...
#
# Preprocessing riga 29...
#
# Preprocessing riga 30...
#
# Preprocessing riga 31...
#
# Preprocessing riga 32...
#
# Preprocessing riga 33...
#
# Preprocessing riga 34...
#
# Preprocessing riga 35...
#
# Preprocessing riga 36...
#
# Preprocessing riga 37...
#
# Preprocessing riga 38...
#
# Preprocessing riga 39...
#
# Preprocessing riga 40...
#
# Preprocessing riga 41...
#
# Preprocessing riga 42...
#
# Preprocessing riga 43...
#
# Preprocessing riga 44...
#
# Preprocessing riga 45...
#
# Preprocessing riga 46...
#
# Preprocessing riga 47...
#
# Preprocessing riga 48...
#
# Preprocessing riga 49...
#
# Preprocessing riga 50...
#
# Preprocessing riga 51...
#
# Preprocessing riga 52...
#
# Preprocessing riga 53...
#
# Preprocessing riga 54...
#
# Preprocessing riga 55...
#
# Preprocessing riga 56...
#
# Preprocessing riga 57...
#
# Preprocessing riga 58...
#
# Preprocessing riga 59...
#
# Preprocessing riga 60...
#
# Preprocessing riga 61...
#
# Preprocessing riga 62...
#
# Preprocessing riga 63...
#
# Preprocessing riga 64...
#
# Preprocessing riga 65...
#
# Preprocessing riga 66...
#
# Preprocessing riga 67...
#
# Preprocessing riga 68...
#
# Preprocessing riga 69...
#
# Preprocessing riga 70...
#
# Preprocessing riga 71...
#
# Preprocessing riga 72...
#
# Preprocessing riga 73...
#
# Preprocessing riga 74...
#
# Preprocessing riga 75...
#
# Preprocessing riga 76...
#
# Preprocessing riga 77...
#
# Preprocessing riga 78...
#
# Preprocessing riga 79...
#
# Preprocessing riga 80...
#
# Preprocessing riga 81...
#
# Preprocessing riga 82...
#
# Preprocessing riga 83...
#
# Preprocessing riga 84...
#
# Preprocessing riga 85...
#
# Preprocessing riga 86...
#
# Preprocessing riga 87...
#
# Preprocessing riga 88...
#
# Preprocessing riga 89...
#
# Preprocessing riga 90...
#
# Preprocessing riga 91...
#
# Preprocessing riga 92...
#
# Preprocessing riga 93...
#
# Preprocessing riga 94...
#
# Preprocessing riga 95...
#
# Preprocessing riga 96...
#
# Preprocessing riga 97...
#
# Preprocessing riga 98...
#
# Preprocessing riga 99...
#
# Preprocessing riga 100...
#
# Preprocessing riga 101...
#
# Preprocessing riga 102...
#
# Preprocessing riga 103...
#
# Preprocessing riga 104...
#
# Preprocessing riga 105...
#
# Preprocessing riga 106...
#
# Preprocessing riga 107...
#
# Preprocessing riga 108...
#
# Preprocessing riga 109...
#
# Preprocessing riga 110...
#
# Preprocessing riga 111...
#
# Preprocessing riga 112...
#
# Preprocessing riga 113...
#
# Preprocessing riga 114...
#
# Preprocessing riga 115...
#
# Preprocessing riga 116...
#
# Preprocessing riga 117...
#
# Preprocessing riga 118...
#
# Preprocessing riga 119...
#
# Preprocessing riga 120...
#
# Preprocessing riga 121...
#
# Preprocessing riga 122...
#
# Preprocessing riga 123...
#
# Preprocessing riga 124...
#
# Preprocessing riga 125...
#
# Preprocessing riga 126...
#
# Preprocessing riga 127...
#
# Preprocessing riga 128...
#
# Preprocessing riga 129...
#
# Preprocessing riga 130...
#
# Preprocessing riga 131...
#
# Preprocessing riga 132...
#
# Preprocessing riga 133...
#
# Preprocessing riga 134...
#
# Preprocessing riga 135...
#
# Preprocessing riga 136...
#
# Preprocessing riga 137...
#
# Preprocessing riga 138...
#
# Preprocessing riga 139...
#
# Preprocessing riga 140...
#
# Preprocessing riga 141...
#
# Preprocessing riga 142...
#
# Preprocessing riga 143...
#
# Preprocessing riga 144...
#
# Preprocessing riga 145...
#
# Preprocessing riga 146...
#
# Preprocessing riga 147...
#
# Preprocessing riga 148...
#
# Preprocessing riga 149...
#
# Preprocessing riga 150...
#
# Preprocessing riga 151...
#
# Preprocessing riga 152...
#
# Preprocessing riga 153...
#
# Preprocessing riga 154...
#
# Preprocessing riga 155...
#
# Preprocessing riga 156...
#
# Preprocessing riga 157...
#
# Preprocessing riga 158...
#
# Preprocessing riga 159...
#
# Preprocessing riga 160...
#
# Preprocessing riga 161...
#
# Preprocessing riga 162...
#
# Preprocessing riga 163...
#
# Preprocessing riga 164...
#
# Preprocessing riga 165...
#
# Preprocessing riga 166...
#
# Preprocessing riga 167...
#
# Preprocessing riga 168...
#
# Preprocessing riga 169...
#
# Preprocessing riga 170...
#
# Preprocessing riga 171...
#
# Preprocessing riga 172...
#
# Preprocessing riga 173...
#
# Preprocessing riga 174...
#
# Preprocessing riga 175...
#
# Preprocessing riga 176...
#
# Preprocessing riga 177...
#
# Preprocessing riga 178...
#
# Preprocessing riga 179...
#
# Preprocessing riga 180...
#
# Preprocessing riga 181...
#
# Preprocessing riga 182...
#
# Preprocessing riga 183...
#
# Preprocessing riga 184...
#
# Preprocessing riga 185...
#
# Preprocessing riga 186...
#
# Preprocessing riga 187...
#
# Preprocessing riga 188...
#
# Preprocessing riga 189...
#
# Preprocessing riga 190...
#
# Preprocessing riga 191...
#
# Preprocessing riga 192...
#
# Preprocessing riga 193...
#
# Preprocessing riga 194...
#
# Preprocessing riga 195...
#
# Preprocessing riga 196...
#
# Preprocessing riga 197...
#
# Preprocessing riga 198...
#
# Preprocessing riga 199...
#
# Preprocessing riga 200...
#
# Preprocessing riga 201...
#
# Preprocessing riga 202...
#
# Preprocessing riga 203...
#
# Preprocessing riga 204...
#
# Preprocessing riga 205...
#
# Preprocessing riga 206...
#
# Preprocessing riga 207...
#
# Preprocessing riga 208...
#
# Preprocessing riga 209...
#
# Preprocessing riga 210...
#
# Preprocessing riga 211...
#
# Preprocessing riga 212...
#
# Preprocessing riga 213...
#
# Preprocessing riga 214...
#
# Preprocessing riga 215...
#
# Preprocessing riga 216...
#
# Preprocessing riga 217...
#
# Preprocessing riga 218...
#
# Preprocessing riga 219...
#
# Preprocessing riga 220...
#
# Preprocessing riga 221...
#
# Preprocessing riga 222...
#
# Preprocessing riga 223...
#
# Preprocessing riga 224...
#
# Preprocessing riga 225...
#
# Preprocessing riga 226...
#
# Preprocessing riga 227...
#
# Preprocessing riga 228...
#
# Preprocessing riga 229...
#
# Preprocessing riga 230...
#
# Preprocessing riga 231...
#
# Preprocessing riga 232...
#
# Preprocessing riga 233...
#
# Preprocessing riga 234...
#
# Preprocessing riga 235...
#
# Preprocessing riga 236...
#
# Preprocessing riga 237...
#
# Preprocessing riga 238...
#
# Preprocessing riga 239...
#
# Preprocessing riga 240...
#
# Preprocessing riga 241...
#
# Preprocessing riga 242...
#
# Preprocessing riga 243...
#
# Preprocessing riga 244...
#
# Preprocessing riga 245...
#
# Preprocessing riga 246...
#
# Preprocessing riga 247...
#
# Preprocessing riga 248...
#
# Preprocessing riga 249...
#
# Preprocessing riga 250...
#
# Preprocessing riga 251...
#
# Preprocessing riga 252...
#
# Preprocessing riga 253...
#
# Preprocessing riga 254...
#
# Preprocessing riga 255...
#
# Preprocessing riga 256...
#
# Preprocessing riga 257...
#
# Preprocessing riga 258...
#
# Preprocessing riga 259...
#
# Preprocessing riga 260...
#
# Preprocessing riga 261...
#
# Preprocessing riga 262...
#
# Preprocessing riga 263...
#
# Preprocessing riga 264...
#
# Preprocessing riga 265...
#
# Preprocessing riga 266...
#
# Preprocessing riga 267...
#
# Preprocessing riga 268...
#
# Preprocessing riga 269...
#
# Preprocessing riga 270...
#
# Preprocessing riga 271...
#
# Preprocessing riga 272...
#
# Preprocessing riga 273...
#
# Preprocessing riga 274...
#
# Preprocessing riga 275...
#
# Preprocessing riga 276...
#
# Preprocessing riga 277...
#
# Preprocessing riga 278...
#
# Preprocessing riga 279...
#
# Preprocessing riga 280...
#
# Preprocessing riga 281...
#
# Preprocessing riga 282...
#
# Preprocessing riga 283...
#
# Preprocessing riga 284...
#
# Preprocessing riga 285...
#
# Preprocessing riga 286...
#
# Preprocessing riga 287...
#
# Preprocessing riga 288...
#
# Preprocessing riga 289...
#
# Preprocessing riga 290...
#
# Preprocessing riga 291...
#
# Preprocessing riga 292...
#
# Preprocessing riga 293...
#
# Preprocessing riga 294...
#
# Preprocessing riga 295...
#
# Preprocessing riga 296...
#
# Preprocessing riga 297...
#
# Preprocessing riga 298...
#
# Preprocessing riga 299...
#
# Preprocessing riga 300...
#
# Preprocessing riga 301...
#
# Preprocessing riga 302...
#
# Preprocessing riga 303...
#
# Preprocessing riga 304...
#
# Preprocessing riga 305...
#
# Preprocessing riga 306...
#
# Preprocessing riga 307...
#
# Preprocessing riga 308...
#
# Preprocessing riga 309...
#
# Preprocessing riga 310...
#
# Preprocessing riga 311...
#
# Preprocessing riga 312...
#
# Preprocessing riga 313...
#
# Preprocessing riga 314...
#
# Preprocessing riga 315...
#
# Preprocessing riga 316...
#
# Preprocessing riga 317...
#
# Preprocessing riga 318...
#
# Preprocessing riga 319...
#
# Preprocessing riga 320...
#
# Preprocessing riga 321...
#
# Preprocessing riga 322...
#
# Preprocessing riga 323...
#
# Preprocessing riga 324...
#
# Preprocessing riga 325...
#
# Preprocessing riga 326...
#
# Preprocessing riga 327...
#
# Preprocessing riga 328...
#
# Preprocessing riga 329...
#
# Preprocessing riga 330...
#
# Preprocessing riga 331...
#
# Preprocessing riga 332...
#
# Preprocessing riga 333...
#
# Preprocessing riga 334...
#
# Preprocessing riga 335...
#
# Preprocessing riga 336...
#
# Preprocessing riga 337...
#
# Preprocessing riga 338...
#
# Preprocessing riga 339...
#
# Preprocessing riga 340...
#
# Preprocessing riga 341...
#
# Preprocessing riga 342...
#
# Preprocessing riga 343...
#
# Preprocessing riga 344...
#
# Preprocessing riga 345...
#
# Preprocessing riga 346...
#
# Preprocessing riga 347...
#
# Preprocessing riga 348...
#
# Preprocessing riga 349...
#
# Preprocessing riga 350...
#
# Preprocessing riga 351...
#
# Preprocessing riga 352...
#
# Preprocessing riga 353...
#
# Preprocessing riga 354...
#
# Preprocessing riga 355...
#
# Preprocessing riga 356...
#
# Preprocessing riga 357...
#
# Preprocessing riga 358...
#
# Preprocessing riga 359...
#
# Preprocessing riga 360...
#
# Preprocessing riga 361...
#
# Preprocessing riga 362...
#
# Preprocessing riga 363...
#
# Preprocessing riga 364...
#
# Preprocessing riga 365...
#
# Preprocessing riga 366...
#
# Preprocessing riga 367...
#
# Preprocessing riga 368...
#
# Preprocessing riga 369...
#
# Preprocessing riga 370...
#
# Preprocessing riga 371...
#
# Preprocessing riga 372...
#
# Preprocessing riga 373...
#
# Preprocessing riga 374...
#
# Preprocessing riga 375...
#
# Preprocessing riga 376...
#
# Preprocessing riga 377...
#
# Preprocessing riga 378...
#
# Preprocessing riga 379...
#
# Preprocessing riga 380...
#
# Preprocessing riga 381...
#
# Preprocessing riga 382...
#
# Preprocessing riga 383...
#
# Preprocessing riga 384...
#
# Preprocessing riga 385...
#
# Preprocessing riga 386...
#
# Preprocessing riga 387...
#
# Preprocessing riga 388...
#
# Preprocessing riga 389...
#
# Preprocessing riga 390...
#
# Preprocessing riga 391...
#
# Preprocessing riga 392...
#
# Preprocessing riga 393...
#
# Preprocessing riga 394...
#
# Preprocessing riga 395...
#
# Preprocessing riga 396...
#
# Preprocessing riga 397...
#
# Preprocessing riga 398...
#
# Preprocessing riga 399...
#
# Preprocessing riga 400...
#
# Preprocessing riga 401...
#
# Preprocessing riga 402...
#
# Preprocessing riga 403...
#
# Preprocessing riga 404...
#
# Preprocessing riga 405...
#
# Preprocessing riga 406...
#
# Preprocessing riga 407...
#
# Preprocessing riga 408...
#
# Preprocessing riga 409...
#
# Preprocessing riga 410...
#
# Preprocessing riga 411...
#
# Preprocessing riga 412...
#
# Preprocessing riga 413...
#
# Preprocessing riga 414...
#
# Preprocessing riga 415...
#
# Preprocessing riga 416...
#
# Preprocessing riga 417...
#
# Preprocessing riga 418...
#
# Preprocessing riga 419...
#
# Preprocessing riga 420...
#
# Preprocessing riga 421...
#
# Preprocessing riga 422...
#
# Preprocessing riga 423...
#
# Preprocessing riga 424...
#
# Preprocessing riga 425...
#
# Preprocessing riga 426...
#
# Preprocessing riga 427...
#
# Preprocessing riga 428...
#
# Preprocessing riga 429...
#
# Preprocessing riga 430...
#
# Preprocessing riga 431...
#
# Preprocessing riga 432...
#
# Preprocessing riga 433...
#
# Preprocessing riga 434...
#
# Preprocessing riga 435...
#
# Preprocessing riga 436...
#
# Preprocessing riga 437...
#
# Preprocessing riga 438...
#
# Preprocessing riga 439...
#
# Preprocessing riga 440...
#
# Preprocessing riga 441...
#
# Preprocessing riga 442...
#
# Preprocessing riga 443...
#
# Preprocessing riga 444...
#
# Preprocessing riga 445...
#
# Preprocessing riga 446...
#
# Preprocessing riga 447...
#
# Preprocessing riga 448...
#
# Preprocessing riga 449...
#
# Preprocessing riga 450...
#
# Preprocessing riga 451...
#
# Preprocessing riga 452...
#
# Preprocessing riga 453...
#
# Preprocessing riga 454...
#
# Preprocessing riga 455...
#
# Preprocessing riga 456...
#
# Preprocessing riga 457...
#
# Preprocessing riga 458...
#
# Preprocessing riga 459...
#
# Preprocessing riga 460...
#
# Preprocessing riga 461...
#
# Preprocessing riga 462...
#
# Preprocessing riga 463...
#
# Preprocessing riga 464...
#
# Preprocessing riga 465...
#
# Preprocessing riga 466...
#
# Preprocessing riga 467...
#
# Preprocessing riga 468...
#
# Preprocessing riga 469...
#
# Preprocessing riga 470...
#
# Preprocessing riga 471...
#
# Preprocessing riga 472...
#
# Preprocessing riga 473...
#
# Preprocessing riga 474...
#
# Preprocessing riga 475...
#
# Preprocessing riga 476...
#
# Preprocessing riga 477...
#
# Preprocessing riga 478...
#
# Preprocessing riga 479...
#
# Preprocessing riga 480...
#
# Preprocessing riga 481...
#
# Preprocessing riga 482...
#
# Preprocessing riga 483...
#
# Preprocessing riga 484...
#
# Preprocessing riga 485...
#
# Preprocessing riga 486...
#
# Preprocessing riga 487...
#
# Preprocessing riga 488...
#
# Preprocessing riga 489...
#
# Preprocessing riga 490...
#
# Preprocessing riga 491...
#
# Preprocessing riga 492...
#
# Preprocessing riga 493...
#
# Preprocessing riga 494...
#
# Preprocessing riga 495...
#
# Preprocessing riga 496...
#
# Preprocessing riga 497...
#
# Preprocessing riga 498...
#
# Preprocessing riga 499...
#
# Preprocessing riga 500...
#
# Preprocessing riga 501...
#
# Preprocessing riga 502...
#
# Preprocessing riga 503...
#
# Preprocessing riga 504...
#
# Preprocessing riga 505...
#
# Preprocessing riga 506...
#
# Preprocessing riga 507...
#
# Preprocessing riga 508...
#
# Preprocessing riga 509...
#
# Preprocessing riga 510...
#
# Preprocessing riga 511...
#
# Preprocessing riga 512...
#
# Preprocessing riga 513...
#
# Preprocessing riga 514...
#
# Preprocessing riga 515...
#
# Preprocessing riga 516...
#
# Preprocessing riga 517...
#
# Preprocessing riga 518...
#
# Preprocessing riga 519...
#
# Preprocessing riga 520...
#
# Preprocessing riga 521...
#
# Preprocessing riga 522...
#
# Preprocessing riga 523...
#
# Preprocessing riga 524...
#
# Preprocessing riga 525...
#
# Preprocessing riga 526...
#
# Preprocessing riga 527...
#
# Preprocessing riga 528...
#
# Preprocessing riga 529...
#
# Preprocessing riga 530...
#
# Preprocessing riga 531...
#
# Preprocessing riga 532...
#
# Preprocessing riga 533...
#
# Preprocessing riga 534...
#
# Preprocessing riga 535...
#
# Preprocessing riga 536...
#
# Preprocessing riga 537...
#
# Preprocessing riga 538...
#
# Preprocessing riga 539...
#
# Preprocessing riga 540...
#
# Preprocessing riga 541...
#
# Preprocessing riga 542...
#
# Preprocessing riga 543...
#
# Preprocessing riga 544...
#
# Preprocessing riga 545...
#
# Preprocessing riga 546...
#
# Preprocessing riga 547...
#
# Preprocessing riga 548...
#
# Preprocessing riga 549...
#
# Preprocessing riga 550...
#
# Preprocessing riga 551...
#
# Preprocessing riga 552...
#
# Preprocessing riga 553...
#
# Preprocessing riga 554...
#
# Preprocessing riga 555...
#
# Preprocessing riga 556...
#
# Preprocessing riga 557...
#
# Preprocessing riga 558...
#
# Preprocessing riga 559...
#
# Preprocessing riga 560...
#
# Preprocessing riga 561...
#
# Preprocessing riga 562...
#
# Preprocessing riga 563...
#
# Preprocessing riga 564...
#
# Preprocessing riga 565...
#
# Preprocessing riga 566...
#
# Preprocessing riga 567...
#
# Preprocessing riga 568...
#
# Preprocessing riga 569...
#
# Preprocessing riga 570...
#
# Preprocessing riga 571...
#
# Preprocessing riga 572...
#
# Preprocessing riga 573...
#
# Preprocessing riga 574...
#
# Preprocessing riga 575...
#
# Preprocessing riga 576...
#
# Preprocessing riga 577...
#
# Preprocessing riga 578...
#
# Preprocessing riga 579...
#
# Preprocessing riga 580...
#
# Preprocessing riga 581...
#
# Preprocessing riga 582...
#
# Preprocessing riga 583...
#
# Preprocessing riga 584...
#
# Preprocessing riga 585...
#
# Preprocessing riga 586...
#
# Preprocessing riga 587...
#
# Preprocessing riga 588...
#
# Preprocessing riga 589...
#
# Preprocessing riga 590...
#
# Preprocessing riga 591...
#
# Preprocessing riga 592...
#
# Preprocessing riga 593...
#
# Preprocessing riga 594...
#
# Preprocessing riga 595...
#
# Preprocessing riga 596...
#
# Preprocessing riga 597...
#
# Preprocessing riga 598...
#
# Preprocessing riga 599...
#
# Preprocessing riga 600...
#
# Preprocessing riga 601...
#
# Preprocessing riga 602...
#
# Preprocessing riga 603...
#
# Preprocessing riga 604...
#
# Preprocessing riga 605...
#
# Preprocessing riga 606...
#
# Preprocessing riga 607...
#
# Preprocessing riga 608...
#
# Preprocessing riga 609...
#
# Preprocessing riga 610...
#
# Preprocessing riga 611...
#
# Preprocessing riga 612...
#
# Preprocessing riga 613...
#
# Preprocessing riga 614...
#
# Preprocessing riga 615...
#
# Preprocessing riga 616...
#
# Preprocessing riga 617...
#
# Preprocessing riga 618...
#
# Preprocessing riga 619...
#
# Preprocessing riga 620...
#
# Preprocessing riga 621...
#
# Preprocessing riga 622...
#
# Preprocessing riga 623...
#
# Preprocessing riga 624...
#
# Preprocessing riga 625...
#
# Preprocessing riga 626...
#
# Preprocessing riga 627...
#
# Preprocessing riga 628...
#
# Preprocessing riga 629...
#
# Preprocessing riga 630...
#
# Preprocessing riga 631...
#
# Preprocessing riga 632...
#
# Preprocessing riga 633...
#
# Preprocessing riga 634...
#
# Preprocessing riga 635...
#
# Preprocessing riga 636...
#
# Preprocessing riga 637...
#
# Preprocessing riga 638...
#
# Preprocessing riga 639...
#
# Preprocessing riga 640...
#
# Preprocessing riga 641...
#
# Preprocessing riga 642...
#
# Preprocessing riga 643...
#
# Preprocessing riga 644...
#
# Preprocessing riga 645...
#
# Preprocessing riga 646...
#
# Preprocessing riga 647...
#
# Preprocessing riga 648...
#
# Preprocessing riga 649...
#
# Preprocessing riga 650...
#
# Preprocessing riga 651...
#
# Preprocessing riga 652...
#
# Preprocessing riga 653...
#
# Preprocessing riga 654...
#
# Preprocessing riga 655...
#
# Preprocessing riga 656...
#
# Preprocessing riga 657...
#
# Preprocessing riga 658...
#
# Preprocessing riga 659...
#
# Preprocessing riga 660...
#
# Preprocessing riga 661...
#
# Preprocessing riga 662...
#
# Preprocessing riga 663...
#
# Preprocessing riga 664...
#
# Preprocessing riga 665...
#
# Preprocessing riga 666...
#
# Preprocessing riga 667...
#
# Preprocessing riga 668...
#
# Preprocessing riga 669...
#
# Preprocessing riga 670...
#
# Preprocessing riga 671...
#
# Preprocessing riga 672...
#
# Preprocessing riga 673...
#
# Preprocessing riga 674...
#
# Preprocessing riga 675...
#
# Preprocessing riga 676...
#
# Preprocessing riga 677...
#
# Preprocessing riga 678...
#
# Preprocessing riga 679...
#
# Preprocessing riga 680...
#
# Preprocessing riga 681...
#
# Preprocessing riga 682...
#
# Preprocessing riga 683...
#
# Preprocessing riga 684...
#
# Preprocessing riga 685...
#
# Preprocessing riga 686...
#
# Preprocessing riga 687...
#
# Preprocessing riga 688...
#
# Preprocessing riga 689...
#
# Preprocessing riga 690...
#
# Preprocessing riga 691...
#
# Preprocessing riga 692...
#
# Preprocessing riga 693...
#
# Preprocessing riga 694...
#
# Preprocessing riga 695...
#
# Preprocessing riga 696...
#
# Preprocessing riga 697...
#
# Preprocessing riga 698...
#
# Preprocessing riga 699...
#
# Preprocessing riga 700...
#
# Preprocessing riga 701...
#
# Preprocessing riga 702...
#
# Preprocessing riga 703...
#
# Preprocessing riga 704...
#
# Preprocessing riga 705...
#
# Preprocessing riga 706...
#
# Preprocessing riga 707...
#
# Preprocessing riga 708...
#
# Preprocessing riga 709...
#
# Preprocessing riga 710...
#
# Preprocessing riga 711...
#
# Preprocessing riga 712...
#
# Preprocessing riga 713...
#
# Preprocessing riga 714...
#
# Preprocessing riga 715...
#
# Preprocessing riga 716...
#
# Preprocessing riga 717...
#
# Preprocessing riga 718...
#
# Preprocessing riga 719...
#
# Preprocessing riga 720...
#
# Preprocessing riga 721...
#
# Preprocessing riga 722...
#
# Preprocessing riga 723...
#
# Preprocessing riga 724...
#
# Preprocessing riga 725...
#
# Preprocessing riga 726...
#
# Preprocessing riga 727...
#
# Preprocessing riga 728...
#
# Preprocessing riga 729...
#
# Preprocessing riga 730...
#
# Preprocessing riga 731...
#
# Preprocessing riga 732...
#
# Preprocessing riga 733...
#
# Preprocessing riga 734...
#
# Preprocessing riga 735...
#
# Preprocessing riga 736...
#
# Preprocessing riga 737...
#
# Preprocessing riga 738...
#
# Preprocessing riga 739...
#
# Preprocessing riga 740...
#
# Preprocessing riga 741...
#
# Preprocessing riga 742...
#
# Preprocessing riga 743...
#
# Preprocessing riga 744...
#
# Preprocessing riga 745...
#
# Preprocessing riga 746...
#
# Preprocessing riga 747...
#
# Preprocessing riga 748...
#
# Preprocessing riga 749...
#
# Preprocessing riga 750...
#
# Preprocessing riga 751...
#
# Preprocessing riga 752...
#
# Preprocessing riga 753...
#
# Preprocessing riga 754...
#
# Preprocessing riga 755...
#
# Preprocessing riga 756...
#
# Preprocessing riga 757...
#
# Preprocessing riga 758...
#
# Preprocessing riga 759...
#
# Preprocessing riga 760...
#
# Preprocessing riga 761...
#
# Preprocessing riga 762...
#
# Preprocessing riga 763...
#
# Preprocessing riga 764...
#
# Preprocessing riga 765...
#
# Preprocessing riga 766...
#
# Preprocessing riga 767...
#
# Preprocessing riga 768...
#
# Preprocessing riga 769...
#
# Preprocessing riga 770...
#
# Preprocessing riga 771...
#
# Preprocessing riga 772...
#
# Preprocessing riga 773...
#
# Preprocessing riga 774...
#
# Preprocessing riga 775...
#
# Preprocessing riga 776...
#
# Preprocessing riga 777...
#
# Preprocessing riga 778...
#
# Preprocessing riga 779...
#
# Preprocessing riga 780...
#
# Preprocessing riga 781...
#
# Preprocessing riga 782...
#
# Preprocessing riga 783...
#
# Preprocessing riga 784...
#
# Preprocessing riga 785...
#
# Preprocessing riga 786...
#
# Preprocessing riga 787...
#
# Preprocessing riga 788...
#
# Preprocessing riga 789...
#
# Preprocessing riga 790...
#
# Preprocessing riga 791...
#
# Preprocessing riga 792...
#
# Preprocessing riga 793...
#
# Preprocessing riga 794...
#
# Preprocessing riga 795...
#
# Preprocessing riga 796...
#
# Preprocessing riga 797...
#
# Preprocessing riga 798...
#
# Preprocessing riga 799...
#
# Preprocessing riga 800...
#
# Preprocessing riga 801...
#
# Preprocessing riga 802...
#
# Preprocessing riga 803...
#
# Preprocessing riga 804...
#
# Preprocessing riga 805...
#
# Preprocessing riga 806...
#
# Preprocessing riga 807...
#
# Preprocessing riga 808...
#
# Preprocessing riga 809...
#
# Preprocessing riga 810...
#
# Preprocessing riga 811...
#
# Preprocessing riga 812...
#
# Preprocessing riga 813...
#
# Preprocessing riga 814...
#
# Preprocessing riga 815...
#
# Preprocessing riga 816...
#
# Preprocessing riga 817...
#
# Preprocessing riga 818...
#
# Preprocessing riga 819...
#
# Preprocessing riga 820...
#
# Preprocessing riga 821...
#
# Preprocessing riga 822...
#
# Preprocessing riga 823...
#
# Preprocessing riga 824...
#
# Preprocessing riga 825...
#
# Preprocessing riga 826...
#
# Preprocessing riga 827...
#
# Preprocessing riga 828...
#
# Preprocessing riga 829...
#
# Preprocessing riga 830...
#
# Preprocessing riga 831...
#
# Preprocessing riga 832...
#
# Preprocessing riga 833...
#
# Preprocessing riga 834...
#
# Preprocessing riga 835...
#
# Preprocessing riga 836...
#
# Preprocessing riga 837...
#
# Preprocessing riga 838...
#
# Preprocessing riga 839...
#
# Preprocessing riga 840...
#
# Preprocessing riga 841...
#
# Preprocessing riga 842...
#
# Preprocessing riga 843...
#
# Preprocessing riga 844...
#
# Preprocessing riga 845...
#
# Preprocessing riga 846...
#
# Preprocessing riga 847...
#
# Preprocessing riga 848...
#
# Preprocessing riga 849...
#
# Preprocessing riga 850...
#
# Preprocessing riga 851...
#
# Preprocessing riga 852...
#
# Preprocessing riga 853...
#
# Preprocessing riga 854...
#
# Preprocessing riga 855...
#
# Preprocessing riga 856...
#
# Preprocessing riga 857...
#
# Preprocessing riga 858...
#
# Preprocessing riga 859...
#
# Preprocessing riga 860...
#
# Preprocessing riga 861...
#
# Preprocessing riga 862...
#
# Preprocessing riga 863...
#
# Preprocessing riga 864...
#
# Preprocessing riga 865...
#
# Preprocessing riga 866...
#
# Preprocessing riga 867...
#
# Preprocessing riga 868...
#
# Preprocessing riga 869...
#
# Preprocessing riga 870...
#
# Preprocessing riga 871...
#
# Preprocessing riga 872...
#
# Preprocessing riga 873...
#
# Preprocessing riga 874...
#
# Preprocessing riga 875...
#
# Preprocessing riga 876...
#
# Preprocessing riga 877...
#
# Preprocessing riga 878...
#
# Preprocessing riga 879...
#
# Preprocessing riga 880...
#
# Preprocessing riga 881...
#
# Preprocessing riga 882...
#
# Preprocessing riga 883...
#
# Preprocessing riga 884...
#
# Preprocessing riga 885...
#
# Preprocessing riga 886...
#
# Preprocessing riga 887...
#
# Preprocessing riga 888...
#
# Preprocessing riga 889...
#
# Preprocessing riga 890...
#
# Preprocessing riga 891...
#
# Preprocessing riga 892...
#
# Preprocessing riga 893...
#
# Preprocessing riga 894...
#
# Preprocessing riga 895...
#
# Preprocessing riga 896...
#
# Preprocessing riga 897...
#
# Preprocessing riga 898...
#
# Preprocessing riga 899...
#
# Preprocessing riga 900...
#
# Preprocessing riga 901...
#
# Preprocessing riga 902...
#
# Preprocessing riga 903...
#
# Preprocessing riga 904...
#
# Preprocessing riga 905...
#
# Preprocessing riga 906...
#
# Preprocessing riga 907...
#
# Preprocessing riga 908...
#
# Preprocessing riga 909...
#
# Preprocessing riga 910...
#
# Preprocessing riga 911...
#
# Preprocessing riga 912...
#
# Preprocessing riga 913...
#
# Preprocessing riga 914...
#
# Preprocessing riga 915...
#
# Preprocessing riga 916...
#
# Preprocessing riga 917...
#
# Preprocessing riga 918...
#
# Preprocessing riga 919...
#
# Preprocessing riga 920...
#
# Preprocessing riga 921...
#
# Preprocessing riga 922...
#
# Preprocessing riga 923...
#
# Preprocessing riga 924...
#
# Preprocessing riga 925...
#
# Preprocessing riga 926...
#
# Preprocessing riga 927...
#
# Preprocessing riga 928...
#
# Preprocessing riga 929...
#
# Preprocessing riga 930...
#
# Preprocessing riga 931...
#
# Preprocessing riga 932...
#
# Preprocessing riga 933...
#
# Preprocessing riga 934...
#
# Preprocessing riga 935...
#
# Preprocessing riga 936...
#
# Preprocessing riga 937...
#
# Preprocessing riga 938...
#
# Preprocessing riga 939...
#
# Preprocessing riga 940...
#
# Preprocessing riga 941...
#
# Preprocessing riga 942...
#
# Preprocessing riga 943...
#
# Preprocessing riga 944...
#
# Preprocessing riga 945...
#
# Preprocessing riga 946...
#
# Preprocessing riga 947...
#
# Preprocessing riga 948...
#
# Preprocessing riga 949...
#
# Preprocessing riga 950...
#
# Preprocessing riga 951...
#
# Preprocessing riga 952...
#
# Preprocessing riga 953...
#
# Preprocessing riga 954...
#
# Preprocessing riga 955...
#
# Preprocessing riga 956...
#
# Preprocessing riga 957...
#
# Preprocessing riga 958...
#
# Preprocessing riga 959...
#
# Preprocessing riga 960...
#
# Preprocessing riga 961...
#
# Preprocessing riga 962...
#
# Preprocessing riga 963...
#
# Preprocessing riga 964...
#
# Preprocessing riga 965...
#
# Preprocessing riga 966...
#
# Preprocessing riga 967...
#
# Preprocessing riga 968...
#
# Preprocessing riga 969...
#
# Preprocessing riga 970...
#
# Preprocessing riga 971...
#
# Preprocessing riga 972...
#
# Preprocessing riga 973...
#
# Preprocessing riga 974...
#
# Preprocessing riga 975...
#
# Preprocessing riga 976...
#
# Preprocessing riga 977...
#
# Preprocessing riga 978...
#
# Preprocessing riga 979...
#
# Preprocessing riga 980...
#
# Preprocessing riga 981...
#
# Preprocessing riga 982...
#
# Preprocessing riga 983...
#
# Preprocessing riga 984...
#
# Preprocessing riga 985...
#
# Preprocessing riga 986...
#
# Preprocessing riga 987...
#
# Preprocessing riga 988...
#
# Preprocessing riga 989...
#
# Preprocessing riga 990...
#
# Preprocessing riga 991...
#
# Preprocessing riga 992...
#
# Preprocessing riga 993...
#
# Preprocessing riga 994...
#
# Preprocessing riga 995...
#
# Preprocessing riga 996...
#
# Preprocessing riga 997...
#
# Preprocessing riga 998...
#
# Preprocessing riga 999...
#
# Preprocessing riga 1000...
#
# Preprocessing riga 1001...
#
# Preprocessing riga 1002...
#
# Preprocessing riga 1003...
#
# Preprocessing riga 1004...
#
# Preprocessing riga 1005...
#
# Preprocessing riga 1006...
#
# Preprocessing riga 1007...
#
# Preprocessing riga 1008...
#
# Preprocessing riga 1009...
#
# Preprocessing riga 1010...
#
# Preprocessing riga 1011...
#
# Preprocessing riga 1012...
#
# Preprocessing riga 1013...
#
# Preprocessing riga 1014...
#
# Preprocessing riga 1015...
#
# Preprocessing riga 1016...
#
# Preprocessing riga 1017...
#
# Preprocessing riga 1018...
#
# Preprocessing riga 1019...
#
# Preprocessing riga 1020...
#
# Preprocessing riga 1021...
#
# Preprocessing riga 1022...
#
# Preprocessing riga 1023...
#
# Preprocessing riga 1024...
#
# Preprocessing riga 1025...
#
# Preprocessing riga 1026...
#
# Preprocessing riga 1027...
#
# Preprocessing riga 1028...
#
# Preprocessing riga 1029...
#
# Preprocessing riga 1030...
#
# Preprocessing riga 1031...
#
# Preprocessing riga 1032...
#
# Preprocessing riga 1033...
#
# Preprocessing riga 1034...
#
# Preprocessing riga 1035...
#
# Preprocessing riga 1036...
#
# Preprocessing riga 1037...
#
# Preprocessing riga 1038...
#
# Preprocessing riga 1039...
#
# Preprocessing riga 1040...
#
# Preprocessing riga 1041...
#
# Preprocessing riga 1042...
#
# Preprocessing riga 1043...
#
# Preprocessing riga 1044...
#
# Preprocessing riga 1045...
#
# Preprocessing riga 1046...
#
# Preprocessing riga 1047...
#
# Preprocessing riga 1048...
#
# Preprocessing riga 1049...
#
# Preprocessing riga 1050...
#
# Preprocessing riga 1051...
#
# Preprocessing riga 1052...
#
# Preprocessing riga 1053...
#
# Preprocessing riga 1054...
#
# Preprocessing riga 1055...
#
# Preprocessing riga 1056...
#
# Preprocessing riga 1057...
#
# Preprocessing riga 1058...
#
# Preprocessing riga 1059...
#
# Preprocessing riga 1060...
#
# Preprocessing riga 1061...
#
# Preprocessing riga 1062...
#
# Preprocessing riga 1063...
#
# Preprocessing riga 1064...
#
# Preprocessing riga 1065...
#
# Preprocessing riga 1066...
#
# Preprocessing riga 1067...
#
# Preprocessing riga 1068...
#
# Preprocessing riga 1069...
#
# Preprocessing riga 1070...
#
# Preprocessing riga 1071...
#
# Preprocessing riga 1072...
#
# Preprocessing riga 1073...
#
# Preprocessing riga 1074...
#
# Preprocessing riga 1075...
#
# Preprocessing riga 1076...
#
# Preprocessing riga 1077...
#
# Preprocessing riga 1078...
#
# Preprocessing riga 1079...
#
# Preprocessing riga 1080...
#
# Preprocessing riga 1081...
#
# Preprocessing riga 1082...
#
# Preprocessing riga 1083...
#
# Preprocessing riga 1084...
#
# Preprocessing riga 1085...
#
# Preprocessing riga 1086...
#
# Preprocessing riga 1087...
#
# Preprocessing riga 1088...
#
# Preprocessing riga 1089...
#
# Preprocessing riga 1090...
#
# Preprocessing riga 1091...
#
# Preprocessing riga 1092...
#
# Preprocessing riga 1093...
#
# Preprocessing riga 1094...
#
# Preprocessing riga 1095...
#
# Preprocessing riga 1096...
#
# Preprocessing riga 1097...
#
# Preprocessing riga 1098...
#
# Preprocessing riga 1099...
#
# Preprocessing riga 1100...
#
# Preprocessing riga 1101...
#
# Preprocessing riga 1102...
#
# Preprocessing riga 1103...
#
# Preprocessing riga 1104...
#
# Preprocessing riga 1105...
#
# Preprocessing riga 1106...
#
# Preprocessing riga 1107...
#
# Preprocessing riga 1108...
#
# Preprocessing riga 1109...
#
# Preprocessing riga 1110...
#
# Preprocessing riga 1111...
#
# Preprocessing riga 1112...
#
# Preprocessing riga 1113...
#
# Preprocessing riga 1114...
#
# Preprocessing riga 1115...
#
# Preprocessing riga 1116...
#
# Preprocessing riga 1117...
#
# Preprocessing riga 1118...
#
# Preprocessing riga 1119...
#
# Preprocessing riga 1120...
#
# Preprocessing riga 1121...
#
# Preprocessing riga 1122...
#
# Preprocessing riga 1123...
#
# Preprocessing riga 1124...
#
# Preprocessing riga 1125...
#
# Preprocessing riga 1126...
#
# Preprocessing riga 1127...
#
# Preprocessing riga 1128...
#
# Preprocessing riga 1129...
#
# Preprocessing riga 1130...
#
# Preprocessing riga 1131...
#
# Preprocessing riga 1132...
#
# Preprocessing riga 1133...
#
# Preprocessing riga 1134...
#
# Preprocessing riga 1135...
#
# Preprocessing riga 1136...
#
# Preprocessing riga 1137...
#
# Preprocessing riga 1138...
#
# Preprocessing riga 1139...
#
# Preprocessing riga 1140...
#
# Preprocessing riga 1141...
#
# Preprocessing riga 1142...
#
# Preprocessing riga 1143...
#
# Preprocessing riga 1144...
#
# Preprocessing riga 1145...
#
# Preprocessing riga 1146...
#
# Preprocessing riga 1147...
#
# Preprocessing riga 1148...
#
# Preprocessing riga 1149...
#
# Preprocessing riga 1150...
#
# Preprocessing riga 1151...
#
# Preprocessing riga 1152...
#
# Preprocessing riga 1153...
#
# Preprocessing riga 1154...
#
# Preprocessing riga 1155...
#
# Preprocessing riga 1156...
#
# Preprocessing riga 1157...
#
# Preprocessing riga 1158...
#
# Preprocessing riga 1159...
#
# Preprocessing riga 1160...
#
# Preprocessing riga 1161...
#
# Preprocessing riga 1162...
#
# Preprocessing riga 1163...
#
# Preprocessing riga 1164...
#
# Preprocessing riga 1165...
#
# Preprocessing riga 1166...
#
# Preprocessing riga 1167...
#
# Preprocessing riga 1168...
#
# Preprocessing riga 1169...
#
# Preprocessing riga 1170...
#
# Preprocessing riga 1171...
#
# Preprocessing riga 1172...
#
# Preprocessing riga 1173...
#
# Preprocessing riga 1174...
#
# Preprocessing riga 1175...
#
# Preprocessing riga 1176...
#
# Preprocessing riga 1177...
#
# Preprocessing riga 1178...
#
# Preprocessing riga 1179...
#
# Preprocessing riga 1180...
#
# Preprocessing riga 1181...
#
# Preprocessing riga 1182...
#
# Preprocessing riga 1183...
#
# Preprocessing riga 1184...
#
# Preprocessing riga 1185...
#
# Preprocessing riga 1186...
#
# Preprocessing riga 1187...
#
# Preprocessing riga 1188...
#
# Preprocessing riga 1189...
#
# Preprocessing riga 1190...
#
# Preprocessing riga 1191...
#
# Preprocessing riga 1192...
#
# Preprocessing riga 1193...
#
# Preprocessing riga 1194...
#
# Preprocessing riga 1195...
#
# Preprocessing riga 1196...
#
# Preprocessing riga 1197...
#
# Preprocessing riga 1198...
#
# Preprocessing riga 1199...
#
# Preprocessing riga 1200...
#
# Preprocessing riga 1201...
#
# Preprocessing riga 1202...
#
# Preprocessing riga 1203...
#
# Preprocessing riga 1204...
#
# Preprocessing riga 1205...
#
# Preprocessing riga 1206...
#
# Preprocessing riga 1207...
#
# Preprocessing riga 1208...
#
# Preprocessing riga 1209...
#
# Preprocessing riga 1210...
#
# Preprocessing riga 1211...
#
# Preprocessing riga 1212...
#
# Preprocessing riga 1213...
#
# Preprocessing riga 1214...
#
# Preprocessing riga 1215...
#
# Preprocessing riga 1216...
#
# Preprocessing riga 1217...
#
# Preprocessing riga 1218...
#
# Preprocessing riga 1219...
#
# Preprocessing riga 1220...
#
# Preprocessing riga 1221...
#
# Preprocessing riga 1222...
#
# Preprocessing riga 1223...
#
# Preprocessing riga 1224...
#
# Preprocessing riga 1225...
#
# Preprocessing riga 1226...
#
# Preprocessing riga 1227...
#
# Preprocessing riga 1228...
#
# Preprocessing riga 1229...
#
# Preprocessing riga 1230...
#
# Preprocessing riga 1231...
#
# Preprocessing riga 1232...
#
# Preprocessing riga 1233...
#
# Preprocessing riga 1234...
#
# Preprocessing riga 1235...
#
# Preprocessing riga 1236...
#
# Preprocessing riga 1237...
#
# Preprocessing riga 1238...
#
# Preprocessing riga 1239...
#
# Preprocessing riga 1240...
#
# Preprocessing riga 1241...
#
# Preprocessing riga 1242...
#
# Preprocessing riga 1243...
#
# Preprocessing riga 1244...
#
# Preprocessing riga 1245...
#
# Preprocessing riga 1246...
#
# Preprocessing riga 1247...
#
# Preprocessing riga 1248...
#
# Preprocessing riga 1249...
#
# Preprocessing riga 1250...
#
# Preprocessing riga 1251...
#
# Preprocessing riga 1252...
#
# Preprocessing riga 1253...
#
# Preprocessing riga 1254...
#
# Preprocessing riga 1255...
#
# Preprocessing riga 1256...
#
# Preprocessing riga 1257...
#
# Preprocessing riga 1258...
#
# Preprocessing riga 1259...
#
# Preprocessing riga 1260...
#
# Preprocessing riga 1261...
#
# Preprocessing riga 1262...
#
# Preprocessing riga 1263...
#
# Preprocessing riga 1264...
#
# Preprocessing riga 1265...
#
# Preprocessing riga 1266...
#
# Preprocessing riga 1267...
#
# Preprocessing riga 1268...
#
# Preprocessing riga 1269...
#
# Preprocessing riga 1270...
#
# Preprocessing riga 1271...
#
# Preprocessing riga 1272...
#
# Preprocessing riga 1273...
#
# Preprocessing riga 1274...
#
# Preprocessing riga 1275...
#
# Preprocessing riga 1276...
#
# Preprocessing riga 1277...
#
# Preprocessing riga 1278...
#
# Preprocessing riga 1279...
#
# Preprocessing riga 1280...
#
# Preprocessing riga 1281...
#
# Preprocessing riga 1282...
#
# Preprocessing riga 1283...
#
# Preprocessing riga 1284...
#
# Preprocessing riga 1285...
#
# Preprocessing riga 1286...
#
# Preprocessing riga 1287...
#
# Preprocessing riga 1288...
#
# Preprocessing riga 1289...
#
# Preprocessing riga 1290...
#
# Preprocessing riga 1291...
#
# Preprocessing riga 1292...
#
# Preprocessing riga 1293...
#
# Preprocessing riga 1294...
#
# Preprocessing riga 1295...
#
# Preprocessing riga 1296...
#
# Preprocessing riga 1297...
#
# Preprocessing riga 1298...
#
# Preprocessing riga 1299...
#
# Preprocessing riga 1300...
#
# Preprocessing riga 1301...
#
# Preprocessing riga 1302...
#
# Preprocessing riga 1303...
#
# Preprocessing riga 1304...
#
# Preprocessing riga 1305...
#
# Preprocessing riga 1306...
#
# Preprocessing riga 1307...
#
# Preprocessing riga 1308...
#
# Preprocessing riga 1309...
#
# Preprocessing riga 1310...
#
# Preprocessing riga 1311...
#
# Preprocessing riga 1312...
#
# Preprocessing riga 1313...
#
# Preprocessing riga 1314...
#
# Preprocessing riga 1315...
#
# Preprocessing riga 1316...
#
# Preprocessing riga 1317...
#
# Preprocessing riga 1318...
#
# Preprocessing riga 1319...
#
# Preprocessing riga 1320...
#
# Preprocessing riga 1321...
#
# Preprocessing riga 1322...
#
# Preprocessing riga 1323...
#
# Preprocessing riga 1324...
#
# Preprocessing riga 1325...
#
# Preprocessing riga 1326...
#
# Preprocessing riga 1327...
#
# Preprocessing riga 1328...
#
# Preprocessing riga 1329...
#
# Preprocessing riga 1330...
#
# Preprocessing riga 1331...
#
# Preprocessing riga 1332...
#
# Preprocessing riga 1333...
#
# Preprocessing riga 1334...
#
# Preprocessing riga 1335...
#
# Preprocessing riga 1336...
#
# Preprocessing riga 1337...
#
# Preprocessing riga 1338...
#
# Preprocessing riga 1339...
#
# Preprocessing riga 1340...
#
# Preprocessing riga 1341...
#
# Preprocessing riga 1342...
#
# Preprocessing riga 1343...
#
# Preprocessing riga 1344...
#
# Preprocessing riga 1345...
#
# Preprocessing riga 1346...
#
# Preprocessing riga 1347...
#
# Preprocessing riga 1348...
#
# Preprocessing riga 1349...
#
# Preprocessing riga 1350...
#
# Preprocessing riga 1351...
#
# Preprocessing riga 1352...
#
# Preprocessing riga 1353...
#
# Preprocessing riga 1354...
#
# Preprocessing riga 1355...
#
# Preprocessing riga 1356...
#
# Preprocessing riga 1357...
#
# Preprocessing riga 1358...
#
# Preprocessing riga 1359...
#
# Preprocessing riga 1360...
#
# Preprocessing riga 1361...
#
# Preprocessing riga 1362...
#
# Preprocessing riga 1363...
#
# Preprocessing riga 1364...
#
# Preprocessing riga 1365...
#
# Preprocessing riga 1366...
#
# Preprocessing riga 1367...
#
# Preprocessing riga 1368...
#
# Preprocessing riga 1369...
#
# Preprocessing riga 1370...
#
# Preprocessing riga 1371...
#
# Preprocessing riga 1372...
#
# Preprocessing riga 1373...
#
# Preprocessing riga 1374...
#
# Preprocessing riga 1375...
#
# Preprocessing riga 1376...
#
# Preprocessing riga 1377...
#
# Preprocessing riga 1378...
#
# Preprocessing riga 1379...
#
# Preprocessing riga 1380...
#
# Preprocessing riga 1381...
#
# Preprocessing riga 1382...
#
# Preprocessing riga 1383...
#
# Preprocessing riga 1384...
#
# Preprocessing riga 1385...
#
# Preprocessing riga 1386...
#
# Preprocessing riga 1387...
#
# Preprocessing riga 1388...
#
# Preprocessing riga 1389...
#
# Preprocessing riga 1390...
#
# Preprocessing riga 1391...
#
# Preprocessing riga 1392...
#
# Preprocessing riga 1393...
#
# Preprocessing riga 1394...
#
# Preprocessing riga 1395...
#
# Preprocessing riga 1396...
#
# Preprocessing riga 1397...
#
# Preprocessing riga 1398...
#
# Preprocessing riga 1399...
#
# Preprocessing riga 1400...
#
# Preprocessing riga 1401...
#
# Preprocessing riga 1402...
#
# Preprocessing riga 1403...
#
# Preprocessing riga 1404...
#
# Preprocessing riga 1405...
#
# Preprocessing riga 1406...
#
# Preprocessing riga 1407...
#
# Preprocessing riga 1408...
#
# Preprocessing riga 1409...
#
# Preprocessing riga 1410...
#
# Preprocessing riga 1411...
#
# Preprocessing riga 1412...
#
# Preprocessing riga 1413...
#
# Preprocessing riga 1414...
#
# Preprocessing riga 1415...
#
# Preprocessing riga 1416...
#
# Preprocessing riga 1417...
#
# Preprocessing riga 1418...
#
# Preprocessing riga 1419...
#
# Preprocessing riga 1420...
#
# Preprocessing riga 1421...
#
# Preprocessing riga 1422...
#
# Preprocessing riga 1423...
#
# Preprocessing riga 1424...
#
# Preprocessing riga 1425...
#
# Preprocessing riga 1426...
#
# Preprocessing riga 1427...
#
# Preprocessing riga 1428...
#
# Preprocessing riga 1429...
#
# Preprocessing riga 1430...
#
# Preprocessing riga 1431...
#
# Preprocessing riga 1432...
#
# Preprocessing riga 1433...
#
# Preprocessing riga 1434...
#
# Preprocessing riga 1435...
#
# Preprocessing riga 1436...
#
# Preprocessing riga 1437...
#
# Preprocessing riga 1438...
#
# Preprocessing riga 1439...
#
# Preprocessing riga 1440...
#
# Preprocessing riga 1441...
#
# Preprocessing riga 1442...
#
# Preprocessing riga 1443...
#
# Preprocessing riga 1444...
#
# Preprocessing riga 1445...
#
# Preprocessing riga 1446...
#
# Preprocessing riga 1447...
#
# Preprocessing riga 1448...
#
# Preprocessing riga 1449...
#
# Preprocessing riga 1450...
#
# Preprocessing riga 1451...
#
# Preprocessing riga 1452...
#
# Preprocessing riga 1453...
#
# Preprocessing riga 1454...
#
# Preprocessing riga 1455...
#
# Preprocessing riga 1456...
#
# Preprocessing riga 1457...
#
# Preprocessing riga 1458...
#
# Preprocessing riga 1459...
#
# Preprocessing riga 1460...
#
# Preprocessing riga 1461...
#
# Preprocessing riga 1462...
#
# Preprocessing riga 1463...
#
# Preprocessing riga 1464...
#
# Preprocessing riga 1465...
#
# Preprocessing riga 1466...
#
# Preprocessing riga 1467...
#
# Preprocessing riga 1468...
#
# Preprocessing riga 1469...
#
# Preprocessing riga 1470...
#
# Preprocessing riga 1471...
#
# Preprocessing riga 1472...
#
# Preprocessing riga 1473...
#
# Preprocessing riga 1474...
#
# Preprocessing riga 1475...
#
# Preprocessing riga 1476...
#
# Preprocessing riga 1477...
#
# Preprocessing riga 1478...
#
# Preprocessing riga 1479...
#
# Preprocessing riga 1480...
#
# Preprocessing riga 1481...
#
# Preprocessing riga 1482...
#
# Preprocessing riga 1483...
#
# Preprocessing riga 1484...
#
# Preprocessing riga 1485...
#
# Preprocessing riga 1486...
#
# Preprocessing riga 1487...
#
# Preprocessing riga 1488...
#
# Preprocessing riga 1489...
#
# Preprocessing riga 1490...
#
# Preprocessing riga 1491...
#
# Preprocessing riga 1492...
#
# Preprocessing riga 1493...
#
# Preprocessing riga 1494...
#
# Preprocessing riga 1495...
#
# Preprocessing riga 1496...
#
# Preprocessing riga 1497...
#
# Preprocessing riga 1498...
#
# Preprocessing riga 1499...
#
# Preprocessing riga 1500...
#
# Preprocessing riga 1501...
#
# Preprocessing riga 1502...
#
# Preprocessing riga 1503...
#
# Preprocessing riga 1504...
#
# Preprocessing riga 1505...
#
# Preprocessing riga 1506...
#
# Preprocessing riga 1507...
#
# Preprocessing riga 1508...
#
# Preprocessing riga 1509...
#
# Preprocessing riga 1510...
#
# Preprocessing riga 1511...
#
# Preprocessing riga 1512...
#
# Preprocessing riga 1513...
#
# Preprocessing riga 1514...
#
# Preprocessing riga 1515...
#
# Preprocessing riga 1516...
#
# Preprocessing riga 1517...
#
# Preprocessing riga 1518...
#
# Preprocessing riga 1519...
#
# Preprocessing riga 1520...
#
# Preprocessing riga 1521...
#
# Preprocessing riga 1522...
#
# Preprocessing riga 1523...
#
# Preprocessing riga 1524...
#
# Preprocessing riga 1525...
#
# Preprocessing riga 1526...
#
# Preprocessing riga 1527...
#
# Preprocessing riga 1528...
#
# Preprocessing riga 1529...
#
# Preprocessing riga 1530...
#
# Preprocessing riga 1531...
#
# Preprocessing riga 1532...
#
# Preprocessing riga 1533...
#
# Preprocessing riga 1534...
#
# Preprocessing riga 1535...
#
# Preprocessing riga 1536...
#
# Preprocessing riga 1537...
#
# Preprocessing riga 1538...
#
# Preprocessing riga 1539...
#
# Preprocessing riga 1540...
#
# Preprocessing riga 1541...
#
# Preprocessing riga 1542...
#
# Preprocessing riga 1543...
#
# Preprocessing riga 1544...
#
# Preprocessing riga 1545...
#
# Preprocessing riga 1546...
#
# Preprocessing riga 1547...
#
# Preprocessing riga 1548...
#
# Preprocessing riga 1549...
#
# Preprocessing riga 1550...
#
# Preprocessing riga 1551...
#
# Preprocessing riga 1552...
#
# Preprocessing riga 1553...
#
# Preprocessing riga 1554...
#
# Preprocessing riga 1555...
#
# Preprocessing riga 1556...
#
# Preprocessing riga 1557...
#
# Preprocessing riga 1558...
#
# Preprocessing riga 1559...
#
# Preprocessing riga 1560...
#
# Preprocessing riga 1561...
#
# Preprocessing riga 1562...
#
# Preprocessing riga 1563...
#
# Preprocessing riga 1564...
#
# Preprocessing riga 1565...
#
# Preprocessing riga 1566...
#
# Preprocessing riga 1567...
#
# Preprocessing riga 1568...
#
# Preprocessing riga 1569...
#
# Preprocessing riga 1570...
#
# Preprocessing riga 1571...
#
# Preprocessing riga 1572...
#
# Preprocessing riga 1573...
#
# Preprocessing riga 1574...
#
# Preprocessing riga 1575...
#
# Preprocessing riga 1576...
#
# Preprocessing riga 1577...
#
# Preprocessing riga 1578...
#
# Preprocessing riga 1579...
#
# Preprocessing riga 1580...
#
# Preprocessing riga 1581...
#
# Preprocessing riga 1582...
#
# Preprocessing riga 1583...
#
# Preprocessing riga 1584...
#
# Preprocessing riga 1585...
#
# Preprocessing riga 1586...
#
# Preprocessing riga 1587...
#
# Preprocessing riga 1588...
#
# Preprocessing riga 1589...
#
# Preprocessing riga 1590...
#
# Preprocessing riga 1591...
#
# Preprocessing riga 1592...
#
# Preprocessing riga 1593...
#
# Preprocessing riga 1594...
#
# Preprocessing riga 1595...
#
# Preprocessing riga 1596...
#
# Preprocessing riga 1597...
#
# Preprocessing riga 1598...
#
# Preprocessing riga 1599...
#
# Preprocessing riga 1600...
#
# Preprocessing riga 1601...
#
# Preprocessing riga 1602...
#
# Preprocessing riga 1603...
#
# Preprocessing riga 1604...
#
# Preprocessing riga 1605...
#
# Preprocessing riga 1606...
#
# Preprocessing riga 1607...
#
# Preprocessing riga 1608...
#
# Preprocessing riga 1609...
#
# Preprocessing riga 1610...
#
# Preprocessing riga 1611...
#
# Preprocessing riga 1612...
#
# Preprocessing riga 1613...
#
# Preprocessing riga 1614...
#
# Preprocessing riga 1615...
#
# Preprocessing riga 1616...
#
# Preprocessing riga 1617...
#
# Preprocessing riga 1618...
#
# Preprocessing riga 1619...
#
# Preprocessing riga 1620...
#
# Preprocessing riga 1621...
#
# Preprocessing riga 1622...
#
# Preprocessing riga 1623...
#
# Preprocessing riga 1624...
#
# Preprocessing riga 1625...
#
# Preprocessing riga 1626...
#
# Preprocessing riga 1627...
#
# Preprocessing riga 1628...
#
# Preprocessing riga 1629...
#
# Preprocessing riga 1630...
#
# Preprocessing riga 1631...
#
# Preprocessing riga 1632...
#
# Preprocessing riga 1633...
#
# Preprocessing riga 1634...
#
# Preprocessing riga 1635...
#
# Preprocessing riga 1636...
#
# Preprocessing riga 1637...
#
# Preprocessing riga 1638...
#
# Preprocessing riga 1639...
#
# Preprocessing riga 1640...
#
# Preprocessing riga 1641...
#
# Preprocessing riga 1642...
#
# Preprocessing riga 1643...
#
# Preprocessing riga 1644...
#
# Preprocessing riga 1645...
#
# Preprocessing riga 1646...
#
# Preprocessing riga 1647...
#
# Preprocessing riga 1648...
#
# Preprocessing riga 1649...
#
# Preprocessing riga 1650...
#
# Preprocessing riga 1651...
#
# Preprocessing riga 1652...
#
# Preprocessing riga 1653...
#
# Preprocessing riga 1654...
#
# Preprocessing riga 1655...
#
# Preprocessing riga 1656...
#
# Preprocessing riga 1657...
#
# Preprocessing riga 1658...
#
# Preprocessing riga 1659...
#
# Preprocessing riga 1660...
#
# Preprocessing riga 1661...
#
# Preprocessing riga 1662...
#
# Preprocessing riga 1663...
#
# Preprocessing riga 1664...
#
# Preprocessing riga 1665...
#
# Preprocessing riga 1666...
#
# Preprocessing riga 1667...
#
# Preprocessing riga 1668...
#
# Preprocessing riga 1669...
#
# Preprocessing riga 1670...
#
# Preprocessing riga 1671...
#
# Preprocessing riga 1672...
#
# Preprocessing riga 1673...
#
# Preprocessing riga 1674...
#
# Preprocessing riga 1675...
#
# Preprocessing riga 1676...
#
# Preprocessing riga 1677...
#
# Preprocessing riga 1678...
#
# Preprocessing riga 1679...
#
# Preprocessing riga 1680...
#
# Preprocessing riga 1681...
#
# Preprocessing riga 1682...
#
# Preprocessing riga 1683...
#
# Preprocessing riga 1684...
#
# Preprocessing riga 1685...
#
# Preprocessing riga 1686...
#
# Preprocessing riga 1687...
#
# Preprocessing riga 1688...
#
# Preprocessing riga 1689...
#
# Preprocessing riga 1690...
#
# Preprocessing riga 1691...
#
# Preprocessing riga 1692...
#
# Preprocessing riga 1693...
#
# Preprocessing riga 1694...
#
# Preprocessing riga 1695...
#
# Preprocessing riga 1696...
#
# Preprocessing riga 1697...
#
# Preprocessing riga 1698...
#
# Preprocessing riga 1699...
#
# Preprocessing riga 1700...
#
# Preprocessing riga 1701...
#
# Preprocessing riga 1702...
#
# Preprocessing riga 1703...
#
# Preprocessing riga 1704...
#
# Preprocessing riga 1705...
#
# Preprocessing riga 1706...
#
# Preprocessing riga 1707...
#
# Preprocessing riga 1708...
#
# Preprocessing riga 1709...
#
# Preprocessing riga 1710...
#
# Preprocessing riga 1711...
#
# Preprocessing riga 1712...
#
# Preprocessing riga 1713...
#
# Preprocessing riga 1714...
#
# Preprocessing riga 1715...
#
# Preprocessing riga 1716...
#
# Preprocessing riga 1717...
#
# Preprocessing riga 1718...
#
# Preprocessing riga 1719...
#
# Preprocessing riga 1720...
#
# Preprocessing riga 1721...
#
# Preprocessing riga 1722...
#
# Preprocessing riga 1723...
#
# Preprocessing riga 1724...
#
# Preprocessing riga 1725...
#
# Preprocessing riga 1726...
#
# Preprocessing riga 1727...
#
# Preprocessing riga 1728...
#
# Preprocessing riga 1729...
#
# Preprocessing riga 1730...
#
# Preprocessing riga 1731...
#
# Preprocessing riga 1732...
#
# Preprocessing riga 1733...
#
# Preprocessing riga 1734...
#
# Preprocessing riga 1735...
#
# Preprocessing riga 1736...
#
# Preprocessing riga 1737...
#
# Preprocessing riga 1738...
#
# Preprocessing riga 1739...
#
# Preprocessing riga 1740...
#
# Preprocessing riga 1741...
#
# Preprocessing riga 1742...
#
# Preprocessing riga 1743...
#
# Preprocessing riga 1744...
#
# Preprocessing riga 1745...
#
# Preprocessing riga 1746...
#
# Preprocessing riga 1747...
#
# Preprocessing riga 1748...
#
# Preprocessing riga 1749...
#
# Preprocessing riga 1750...
#
# Preprocessing riga 1751...
#
# Preprocessing riga 1752...
# ...
#
# Preprocessing riga 5204...
#
# Preprocessing riga 5205...
#
# Preprocessing riga 5206...
#
# Preprocessing riga 5207...
#
# Preprocessing riga 5208...
#
# Preprocessing riga 5209...
#
# Preprocessing riga 5210...
#
# Preprocessing riga 5211...
#
# Preprocessing riga 5212...
#
# Preprocessing riga 5213...
#
# Preprocessing riga 5214...
#
# Preprocessing riga 5215...
#
# Preprocessing riga 5216...
#
# Preprocessing riga 5217...
#
# Preprocessing riga 5218...
#
# Preprocessing riga 5219...
#
# Preprocessing riga 5220...
#
# Preprocessing riga 5221...
#
# Preprocessing riga 5222...
#
# Preprocessing riga 5223...
#
# Preprocessing riga 5224...
#
# Preprocessing riga 5225...
#
# Preprocessing riga 5226...
#
# Preprocessing riga 5227...
#
# Preprocessing riga 5228...
#
# Preprocessing riga 5229...
#
# Preprocessing riga 5230...
#
# Preprocessing riga 5231...
#
# Preprocessing riga 5232...
#
# Preprocessing riga 5233...
#
# Preprocessing riga 5234...
#
# Preprocessing riga 5235...
#
# Preprocessing riga 5236...
#
# Preprocessing riga 5237...
#
# Preprocessing riga 5238...
#
# Preprocessing riga 5239...
#
# Preprocessing riga 5240...
#
# Preprocessing riga 5241...
#
# Preprocessing riga 5242...
#
# Preprocessing riga 5243...
#
# Preprocessing riga 5244...
#
# Preprocessing riga 5245...
#
# Preprocessing riga 5246...
#
# Preprocessing riga 5247...
#
# Preprocessing riga 5248...
#
# Preprocessing riga 5249...
#
# Preprocessing riga 5250...
#
# Preprocessing riga 5251...
#
# Preprocessing riga 5252...
#
# Preprocessing riga 5253...
#
# Preprocessing riga 5254...
#
# Preprocessing riga 5255...
#
# Preprocessing riga 5256...
#
# Preprocessing riga 5257...
#
# Preprocessing riga 5258...
#
# Preprocessing riga 5259...
#
# Preprocessing riga 5260...
#
# Preprocessing riga 5261...
#
# Preprocessing riga 5262...
#
# Preprocessing riga 5263...
#
# Preprocessing riga 5264...
#
# Preprocessing riga 5265...
#
# Preprocessing riga 5266...
#
# Preprocessing riga 5267...
#
# Preprocessing riga 5268...
#
# Preprocessing riga 5269...
#
# Preprocessing riga 5270...
#
# Preprocessing riga 5271...
#
# Preprocessing riga 5272...
#
# Preprocessing riga 5273...
#
# Preprocessing riga 5274...
#
# Preprocessing riga 5275...
#
# Preprocessing riga 5276...
#
# Preprocessing riga 5277...
#
# Preprocessing riga 5278...
#
# Preprocessing riga 5279...
#
# Preprocessing riga 5280...
#
# Preprocessing riga 5281...
#
# Preprocessing riga 5282...
#
# Preprocessing riga 5283...
#
# Preprocessing riga 5284...
#
# Preprocessing riga 5285...
#
# Preprocessing riga 5286...
#
# Preprocessing riga 5287...
#
# Preprocessing riga 5288...
#
# Preprocessing riga 5289...
#
# Preprocessing riga 5290...
#
# Preprocessing riga 5291...
#
# Preprocessing riga 5292...
#
# Preprocessing riga 5293...
#
# Preprocessing riga 5294...
#
# Preprocessing riga 5295...
#
# Preprocessing riga 5296...
#
# Preprocessing riga 5297...
#
# Preprocessing riga 5298...
#
# Preprocessing riga 5299...
#
# Preprocessing riga 5300...
#
# Preprocessing riga 5301...
#
# Preprocessing riga 5302...
#
# Preprocessing riga 5303...
#
# Preprocessing riga 5304...
#
# Preprocessing riga 5305...
#
# Preprocessing riga 5306...
#
# Preprocessing riga 5307...
#
# Preprocessing riga 5308...
#
# Preprocessing riga 5309...
#
# Preprocessing riga 5310...
#
# Preprocessing riga 5311...
#
# Preprocessing riga 5312...
#
# Preprocessing riga 5313...
#
# Preprocessing riga 5314...
#
# Preprocessing riga 5315...
#
# Preprocessing riga 5316...
#
# Preprocessing riga 5317...
#
# Preprocessing riga 5318...
#
# Preprocessing riga 5319...
#
# Preprocessing riga 5320...
#
# Preprocessing riga 5321...
#
# Preprocessing riga 5322...
#
# Preprocessing riga 5323...
#
# Preprocessing riga 5324...
#
# Preprocessing riga 5325...
#
# Preprocessing riga 5326...
#
# Preprocessing riga 5327...
#
# Preprocessing riga 5328...
#
# Preprocessing riga 5329...
#
# Preprocessing riga 5330...
#
# Preprocessing riga 5331...
#
# Preprocessing riga 5332...
#
# Preprocessing riga 5333...
#
# Preprocessing riga 5334...
#
# Preprocessing riga 5335...
#
# Preprocessing riga 5336...
#
# Preprocessing riga 5337...
#
# Preprocessing riga 5338...
#
# Preprocessing riga 5339...
#
# Preprocessing riga 5340...
#
# Preprocessing riga 5341...
#
# Preprocessing riga 5342...
#
# Preprocessing riga 5343...
#
# Preprocessing riga 5344...
#
# Preprocessing riga 5345...
#
# Preprocessing riga 5346...
#
# Preprocessing riga 5347...
#
# Preprocessing riga 5348...
#
# Preprocessing riga 5349...
#
# Preprocessing riga 5350...
#
# Preprocessing riga 5351...
#
# Preprocessing riga 5352...
#
# Preprocessing riga 5353...
#
# Preprocessing riga 5354...
#
# Preprocessing riga 5355...
#
# Preprocessing riga 5356...
#
# Preprocessing riga 5357...
#
# Preprocessing riga 5358...
#
# Preprocessing riga 5359...
#
# Preprocessing riga 5360...
#
# Preprocessing riga 5361...
#
# Preprocessing riga 5362...
#
# Preprocessing riga 5363...
#
# Preprocessing riga 5364...
#
# Preprocessing riga 5365...
#
# Preprocessing riga 5366...
#
# Preprocessing riga 5367...
#
# Preprocessing riga 5368...
#
# Preprocessing riga 5369...
#
# Preprocessing riga 5370...
#
# Preprocessing riga 5371...
#
# Preprocessing riga 5372...
#
# Preprocessing riga 5373...
#
# Preprocessing riga 5374...
#
# Preprocessing riga 5375...
#
# Preprocessing riga 5376...
#
# Preprocessing riga 5377...
#
# Preprocessing riga 5378...
#
# Preprocessing riga 5379...
#
# Preprocessing riga 5380...
#
# Preprocessing riga 5381...
#
# Preprocessing riga 5382...
#
# Preprocessing riga 5383...
#
# Preprocessing riga 5384...
#
# Preprocessing riga 5385...
#
# Preprocessing riga 5386...
#
# Preprocessing riga 5387...
#
# Preprocessing riga 5388...
#
# Preprocessing riga 5389...
#
# Preprocessing riga 5390...
#
# Preprocessing riga 5391...
#
# Preprocessing riga 5392...
#
# Preprocessing riga 5393...
#
# Preprocessing riga 5394...
#
# Preprocessing riga 5395...
#
# Preprocessing riga 5396...
#
# Preprocessing riga 5397...
#
# Preprocessing riga 5398...
#
# Preprocessing riga 5399...
#
# Preprocessing riga 5400...
#
# Preprocessing riga 5401...
#
# Preprocessing riga 5402...
#
# Preprocessing riga 5403...
#
# Preprocessing riga 5404...
#
# Preprocessing riga 5405...
#
# Preprocessing riga 5406...
#
# Preprocessing riga 5407...
#
# Preprocessing riga 5408...
#
# Preprocessing riga 5409...
#
# Preprocessing riga 5410...
#
# Preprocessing riga 5411...
#
# Preprocessing riga 5412...
#
# Preprocessing riga 5413...
#
# Preprocessing riga 5414...
#
# Preprocessing riga 5415...
#
# Preprocessing riga 5416...
#
# Preprocessing riga 5417...
#
# Preprocessing riga 5418...
#
# Preprocessing riga 5419...
#
# Preprocessing riga 5420...
#
# Preprocessing riga 5421...
#
# Preprocessing riga 5422...
#
# Preprocessing riga 5423...
#
# Preprocessing riga 5424...
#
# Preprocessing riga 5425...
#
# Preprocessing riga 5426...
#
# Preprocessing riga 5427...
#
# Preprocessing riga 5428...
#
# Preprocessing riga 5429...
#
# Preprocessing riga 5430...
#
# Preprocessing riga 5431...
#
# Preprocessing riga 5432...
#
# Preprocessing riga 5433...
#
# Preprocessing riga 5434...
#
# Preprocessing riga 5435...
#
# Preprocessing riga 5436...
#
# Preprocessing riga 5437...
#
# Preprocessing riga 5438...
#
# Preprocessing riga 5439...
#
# Preprocessing riga 5440...
#
# Preprocessing riga 5441...
#
# Preprocessing riga 5442...
#
# Preprocessing riga 5443...
#
# Preprocessing riga 5444...
#
# Preprocessing riga 5445...
#
# Preprocessing riga 5446...
#
# Preprocessing riga 5447...
#
# Preprocessing riga 5448...
#
# Preprocessing riga 5449...
#
# Preprocessing riga 5450...
#
# Preprocessing riga 5451...
#
# Preprocessing riga 5452...
#
# Preprocessing riga 5453...
#
# Preprocessing riga 5454...
#
# Preprocessing riga 5455...
#
# Preprocessing riga 5456...
#
# Preprocessing riga 5457...
#
# Preprocessing riga 5458...
#
# Preprocessing riga 5459...
#
# Preprocessing riga 5460...
#
# Preprocessing riga 5461...
#
# Preprocessing riga 5462...
#
# Preprocessing riga 5463...
#
# Preprocessing riga 5464...
#
# Preprocessing riga 5465...
#
# Preprocessing riga 5466...
#
# Preprocessing riga 5467...
#
# Preprocessing riga 5468...
#
# Preprocessing riga 5469...
#
# Preprocessing riga 5470...
#
# Preprocessing riga 5471...
#
# Preprocessing riga 5472...
#
# Preprocessing riga 5473...
#
# Preprocessing riga 5474...
#
# Preprocessing riga 5475...
#
# Preprocessing riga 5476...
#
# Preprocessing riga 5477...
#
# Preprocessing riga 5478...
#
# Preprocessing riga 5479...
#
# Preprocessing riga 5480...
#
# Preprocessing riga 5481...
#
# Preprocessing riga 5482...
#
# Preprocessing riga 5483...
#
# Preprocessing riga 5484...
#
# Preprocessing riga 5485...
#
# Preprocessing riga 5486...
#
# Preprocessing riga 5487...
#
# Preprocessing riga 5488...
#
# Preprocessing riga 5489...
#
# Preprocessing riga 5490...
#
# Preprocessing riga 5491...
#
# Preprocessing riga 5492...
#
# Preprocessing riga 5493...
#
# Preprocessing riga 5494...
#
# Preprocessing riga 5495...
#
# Preprocessing riga 5496...
#
# Preprocessing riga 5497...
#
# Preprocessing riga 5498...
#
# Preprocessing riga 5499...
#
# Preprocessing riga 5500...
#
# Preprocessing riga 5501...
#
# Preprocessing riga 5502...
#
# Preprocessing riga 5503...
#
# Preprocessing riga 5504...
#
# Preprocessing riga 5505...
#
# Preprocessing riga 5506...
#
# Preprocessing riga 5507...
#
# Preprocessing riga 5508...
#
# Preprocessing riga 5509...
#
# Preprocessing riga 5510...
#
# Preprocessing riga 5511...
#
# Preprocessing riga 5512...
#
# Preprocessing riga 5513...
#
# Preprocessing riga 5514...
#
# Preprocessing riga 5515...
#
# Preprocessing riga 5516...
#
# Preprocessing riga 5517...
#
# Preprocessing riga 5518...
#
# Preprocessing riga 5519...
#
# Preprocessing riga 5520...
#
# Preprocessing riga 5521...
#
# Preprocessing riga 5522...
#
# Preprocessing riga 5523...
#
# Preprocessing riga 5524...
#
# Preprocessing riga 5525...
#
# Preprocessing riga 5526...
#
# Preprocessing riga 5527...
#
# Preprocessing riga 5528...
#
# Preprocessing riga 5529...
#
# Preprocessing riga 5530...
#
# Preprocessing riga 5531...
#
# Preprocessing riga 5532...
#
# Preprocessing riga 5533...
#
# Preprocessing riga 5534...
#
# Preprocessing riga 5535...
#
# Preprocessing riga 5536...
#
# Preprocessing riga 5537...
#
# Preprocessing riga 5538...
#
# Preprocessing riga 5539...
#
# Preprocessing riga 5540...
#
# Preprocessing riga 5541...
#
# Preprocessing riga 5542...
#
# Preprocessing riga 5543...
#
# Preprocessing riga 5544...
#
# Preprocessing riga 5545...
#
# Preprocessing riga 5546...
#
# Preprocessing riga 5547...
#
# Preprocessing riga 5548...
#
# Preprocessing riga 5549...
#
# Preprocessing riga 5550...
#
# Preprocessing riga 5551...
#
# Preprocessing riga 5552...
#
# Preprocessing riga 5553...
#
# Preprocessing riga 5554...
#
# Preprocessing riga 5555...
#
# Preprocessing riga 5556...
#
# Preprocessing riga 5557...
#
# Preprocessing riga 5558...
#
# Preprocessing riga 5559...
#
# Preprocessing riga 5560...
#
# Preprocessing riga 5561...
#
# Preprocessing riga 5562...
#
# Preprocessing riga 5563...
#
# Preprocessing riga 5564...
#
# Preprocessing riga 5565...
#
# Preprocessing riga 5566...
#
# Preprocessing riga 5567...
#
# Preprocessing riga 5568...
#
# Preprocessing riga 5569...
#
# Preprocessing riga 5570...
#
# Preprocessing riga 5571...
#
# Preprocessing riga 5572...
#
# Preprocessing riga 5573...
#
# Preprocessing riga 5574...
#
# Preprocessing riga 5575...
#
# Preprocessing riga 5576...
#
# Preprocessing riga 5577...
#
# Preprocessing riga 5578...
#
# Preprocessing riga 5579...
#
# Preprocessing riga 5580...
#
# Preprocessing riga 5581...
#
# Preprocessing riga 5582...
#
# Preprocessing riga 5583...
#
# Preprocessing riga 5584...
#
# Preprocessing riga 5585...
#
# Preprocessing riga 5586...
#
# Preprocessing riga 5587...
#
# Preprocessing riga 5588...
#
# Preprocessing riga 5589...
#
# Preprocessing riga 5590...
#
# Preprocessing riga 5591...
#
# Preprocessing riga 5592...
#
# Preprocessing riga 5593...
#
# Preprocessing riga 5594...
#
# Preprocessing riga 5595...
#
# Preprocessing riga 5596...
#
# Preprocessing riga 5597...
#
# Preprocessing riga 5598...
#
# Preprocessing riga 5599...
#
# Preprocessing riga 5600...
#
# Preprocessing riga 5601...
#
# Preprocessing riga 5602...
#
# Preprocessing riga 5603...
#
# Preprocessing riga 5604...
#
# Preprocessing riga 5605...
#
# Preprocessing riga 5606...
#
# Preprocessing riga 5607...
#
# Preprocessing riga 5608...
#
# Preprocessing riga 5609...
#
# Preprocessing riga 5610...
#
# Preprocessing riga 5611...
#
# Preprocessing riga 5612...
#
# Preprocessing riga 5613...
#
# Preprocessing riga 5614...
#
# Preprocessing riga 5615...
#
# Preprocessing riga 5616...
#
# Preprocessing riga 5617...
#
# Preprocessing riga 5618...
#
# Preprocessing riga 5619...
#
# Preprocessing riga 5620...
#
# Preprocessing riga 5621...
#
# Preprocessing riga 5622...
#
# Preprocessing riga 5623...
#
# Preprocessing riga 5624...
#
# Preprocessing riga 5625...
#
# Preprocessing riga 5626...
#
# Preprocessing riga 5627...
#
# Preprocessing riga 5628...
#
# Preprocessing riga 5629...
#
# Preprocessing riga 5630...
#
# Preprocessing riga 5631...
#
# Preprocessing riga 5632...
#
# Preprocessing riga 5633...
#
# Preprocessing riga 5634...
#
# Preprocessing riga 5635...
#
# Preprocessing riga 5636...
#
# Preprocessing riga 5637...
#
# Preprocessing riga 5638...
#
# Preprocessing riga 5639...
#
# Preprocessing riga 5640...
#
# Preprocessing riga 5641...
#
# Preprocessing riga 5642...
#
# Preprocessing riga 5643...
#
# Preprocessing riga 5644...
#
# Preprocessing riga 5645...
#
# Preprocessing riga 5646...
#
# Preprocessing riga 5647...
#
# Preprocessing riga 5648...
#
# Preprocessing riga 5649...
#
# Preprocessing riga 5650...
#
# Preprocessing riga 5651...
#
# Preprocessing riga 5652...
#
# Preprocessing riga 5653...
#
# Preprocessing riga 5654...
#
# Preprocessing riga 5655...
#
# Preprocessing riga 5656...
#
# Preprocessing riga 5657...
#
# Preprocessing riga 5658...
#
# Preprocessing riga 5659...
#
# Preprocessing riga 5660...
#
# Preprocessing riga 5661...
#
# Preprocessing riga 5662...
#
# Preprocessing riga 5663...
#
# Preprocessing riga 5664...
#
# Preprocessing riga 5665...
#
# Preprocessing riga 5666...
#
# Preprocessing riga 5667...
#
# Preprocessing riga 5668...
#
# Preprocessing riga 5669...
#
# Preprocessing riga 5670...
#
# Preprocessing riga 5671...
#
# Preprocessing riga 5672...
#
# Preprocessing riga 5673...
#
# Preprocessing riga 5674...
#
# Preprocessing riga 5675...
#
# Preprocessing riga 5676...
#
# Preprocessing riga 5677...
#
# Preprocessing riga 5678...
#
# Preprocessing riga 5679...
#
# Preprocessing riga 5680...
#
# Preprocessing riga 5681...
#
# Preprocessing riga 5682...
#
# Preprocessing riga 5683...
#
# Preprocessing riga 5684...
#
# Preprocessing riga 5685...
#
# Preprocessing riga 5686...
#
# Preprocessing riga 5687...
#
# Preprocessing riga 5688...
#
# Preprocessing riga 5689...
#
# Preprocessing riga 5690...
#
# Preprocessing riga 5691...
#
# Preprocessing riga 5692...
#
# Preprocessing riga 5693...
#
# Preprocessing riga 5694...
#
# Preprocessing riga 5695...
#
# Preprocessing riga 5696...
#
# Preprocessing riga 5697...
#
# Preprocessing riga 5698...
#
# Preprocessing riga 5699...
#
# Preprocessing riga 5700...
#
# Preprocessing riga 5701...
#
# Preprocessing riga 5702...
#
# Preprocessing riga 5703...
#
# Preprocessing riga 5704...
#
# Preprocessing riga 5705...
#
# Preprocessing riga 5706...
#
# Preprocessing riga 5707...
#
# Preprocessing riga 5708...
#
# Preprocessing riga 5709...
#
# Preprocessing riga 5710...
#
# Preprocessing riga 5711...
#
# Preprocessing riga 5712...
#
# Preprocessing riga 5713...
#
# Preprocessing riga 5714...
#
# Preprocessing riga 5715...
#
# Preprocessing riga 5716...
#
# Preprocessing riga 5717...
#
# Preprocessing riga 5718...
#
# Preprocessing riga 5719...
#
# Preprocessing riga 5720...
#
# Preprocessing riga 5721...
#
# Preprocessing riga 5722...
#
# Preprocessing riga 5723...
#
# Preprocessing riga 5724...
#
# Preprocessing riga 5725...
#
# Preprocessing riga 5726...
#
# Preprocessing riga 5727...
#
# Preprocessing riga 5728...
#
# Preprocessing riga 5729...
#
# Preprocessing riga 5730...
#
# Preprocessing riga 5731...
#
# Preprocessing riga 5732...
#
# Preprocessing riga 5733...
#
# Preprocessing riga 5734...
#
# Preprocessing riga 5735...
#
# Preprocessing riga 5736...
#
# Preprocessing riga 5737...
#
# Preprocessing riga 5738...
#
# Preprocessing riga 5739...
#
# Preprocessing riga 5740...
#
# Preprocessing riga 5741...
#
# Preprocessing riga 5742...
#
# Preprocessing riga 5743...
#
# Preprocessing riga 5744...
#
# Preprocessing riga 5745...
#
# Preprocessing riga 5746...
#
# Preprocessing riga 5747...
#
# Preprocessing riga 5748...
#
# Preprocessing riga 5749...
#
# Preprocessing riga 5750...
#
# Preprocessing riga 5751...
#
# Preprocessing riga 5752...
#
# Preprocessing riga 5753...
#
# Preprocessing riga 5754...
#
# Preprocessing riga 5755...
#
# Preprocessing riga 5756...
#
# Preprocessing riga 5757...
#
# Preprocessing riga 5758...
#
# Preprocessing riga 5759...
#
# Preprocessing riga 5760...
#
# Preprocessing riga 5761...
#
# Preprocessing riga 5762...
#
# Preprocessing riga 5763...
#
# Preprocessing riga 5764...
#
# Preprocessing riga 5765...
#
# Preprocessing riga 5766...
#
# Preprocessing riga 5767...
#
# Preprocessing riga 5768...
#
# Preprocessing riga 5769...
#
# Preprocessing riga 5770...
#
# Preprocessing riga 5771...
#
# Preprocessing riga 5772...
#
# Preprocessing riga 5773...
#
#
# Matrix X: (5774, 5944)

# %%
print(f"Label y: {set(y)}")
# Out:
# Label y: {'Reggae', 'Jazz', 'Funk', 'Soul', 'House', 'Dubstep', 'Electronic', 'Blues', 'Disco', 'Pop', 'Classical', 'Hip-Hop', 'Drum and Bass', 'R&B', 'Techno', 'Country', 'Folk', 'Punk', 'Metal', 'Trance', 'Rock'}

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import joblib
# === 1. Normalizzazione delle feature (StandardScaler) ===
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
joblib.dump(scaler, "scaler_sicuro.pkl")
# Out:
# ['scaler_sicuro.pkl']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  # y → array di interi
joblib.dump(scaler, "labelEncoder_sicuro.pkl")
# Out:
# ['labelEncoder_sicuro.pkl']

# %%
# # === 1. Prima split: 95% train_val, 5% test ===
# X_train_val, X_test, y_train_val, y_test = train_test_split(
#     X_scaled, y_encoded, test_size=0.05, random_state=42, stratify=y_encoded
# )

# # === 2. Seconda split: da train_val → 75% train, 20% val ===
# # Calcolo proporzione della val set su train_val (20 / 95 ≈ 0.2105)
# val_size = 0.20 / 0.95

# X_train, X_val, y_train, y_val = train_test_split(
#     X_train_val, y_train_val, test_size=val_size, random_state=42, stratify=y_train_val
# )

X_training, X_val, y_training, y_val = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=123, stratify=y_encoded
)

# %%
X_train_tensor = torch.tensor(X_training, dtype=torch.float32)
X_val_tensor   = torch.tensor(X_val, dtype=torch.float32)
#X_test_tensor  = torch.tensor(X_test, dtype=torch.float32)

y_train_tensor = torch.tensor(y_training, dtype=torch.long)
y_val_tensor   = torch.tensor(y_val, dtype=torch.long)
#y_test_tensor  = torch.tensor(y_test, dtype=torch.long)

# %%
import torch.nn as nn

# Numero di feature in input
input_size = X_train_tensor.shape[1]
print(f"\nNumero di feature in input: {input_size}")
num_classes = len(np.unique(y_encoded))
print(f"Numero di classi: {num_classes}")

# Modello semplice: input → 128 → ReLU → 64 → ReLU → output
class MusicGenreClassifier(nn.Module):
    def __init__(self):
        super(MusicGenreClassifier, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 1000),
            nn.ReLU(),
            nn.Linear(1000, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            #nn.ReLU(),
            #nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        return self.net(x)

model = MusicGenreClassifier()
# Out:
# Numero di feature in input: 5944
# Numero di classi: 21

# %%
epochs = 50
lr = 0.001
print(f"\nLearning rate: {lr}")
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()

    # Valutazione su validation set
    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)
        val_preds = torch.argmax(val_outputs, dim=1)
        val_acc = (val_preds == y_val_tensor).float().mean()

    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {loss.item():.4f} | Val Loss: {val_loss.item():.4f} | Val Acc: {val_acc:.4f}")
# Out:
# Learning rate: 0.001
# Epoch 1/50 | Train Loss: 3.0361 | Val Loss: 2.8088 | Val Acc: 0.1602
# Epoch 2/50 | Train Loss: 2.7912 | Val Loss: 2.5820 | Val Acc: 0.1905
# Epoch 3/50 | Train Loss: 2.5610 | Val Loss: 2.4081 | Val Acc: 0.2537
# Epoch 4/50 | Train Loss: 2.3391 | Val Loss: 2.2933 | Val Acc: 0.3022
# Epoch 5/50 | Train Loss: 2.1848 | Val Loss: 2.2347 | Val Acc: 0.3221
# Epoch 6/50 | Train Loss: 2.0756 | Val Loss: 2.1612 | Val Acc: 0.3316
# Epoch 7/50 | Train Loss: 1.9570 | Val Loss: 2.0595 | Val Acc: 0.3654
# Epoch 8/50 | Train Loss: 1.8165 | Val Loss: 2.0093 | Val Acc: 0.3853
# Epoch 9/50 | Train Loss: 1.7235 | Val Loss: 1.9179 | Val Acc: 0.4087
# Epoch 10/50 | Train Loss: 1.5902 | Val Loss: 1.8669 | Val Acc: 0.4173
# Epoch 11/50 | Train Loss: 1.4899 | Val Loss: 1.8148 | Val Acc: 0.4320
# Epoch 12/50 | Train Loss: 1.3958 | Val Loss: 1.7640 | Val Acc: 0.4494
# Epoch 13/50 | Train Loss: 1.2904 | Val Loss: 1.7586 | Val Acc: 0.4528
# Epoch 14/50 | Train Loss: 1.1975 | Val Loss: 1.7364 | Val Acc: 0.4649
# Epoch 15/50 | Train Loss: 1.1075 | Val Loss: 1.6941 | Val Acc: 0.4840
# Epoch 16/50 | Train Loss: 1.0133 | Val Loss: 1.6807 | Val Acc: 0.4840
# Epoch 17/50 | Train Loss: 0.9297 | Val Loss: 1.6611 | Val Acc: 0.4909
# Epoch 18/50 | Train Loss: 0.8350 | Val Loss: 1.6663 | Val Acc: 0.4918
# Epoch 19/50 | Train Loss: 0.7652 | Val Loss: 1.6438 | Val Acc: 0.5074
# Epoch 20/50 | Train Loss: 0.6771 | Val Loss: 1.6268 | Val Acc: 0.5108
# Epoch 21/50 | Train Loss: 0.6059 | Val Loss: 1.6302 | Val Acc: 0.5100
# Epoch 22/50 | Train Loss: 0.5378 | Val Loss: 1.6458 | Val Acc: 0.5134
# Epoch 23/50 | Train Loss: 0.4642 | Val Loss: 1.6664 | Val Acc: 0.5169
# Epoch 24/50 | Train Loss: 0.4032 | Val Loss: 1.6739 | Val Acc: 0.5048
# Epoch 25/50 | Train Loss: 0.3420 | Val Loss: 1.7022 | Val Acc: 0.5126
# Epoch 26/50 | Train Loss: 0.2932 | Val Loss: 1.7080 | Val Acc: 0.5255
# Epoch 27/50 | Train Loss: 0.2395 | Val Loss: 1.7401 | Val Acc: 0.5091
# Epoch 28/50 | Train Loss: 0.2027 | Val Loss: 1.7651 | Val Acc: 0.5117
# Epoch 29/50 | Train Loss: 0.1619 | Val Loss: 1.8160 | Val Acc: 0.5065
# Epoch 30/50 | Train Loss: 0.1370 | Val Loss: 1.8226 | Val Acc: 0.5091
# Epoch 31/50 | Train Loss: 0.1056 | Val Loss: 1.8605 | Val Acc: 0.5082
# Epoch 32/50 | Train Loss: 0.0873 | Val Loss: 1.9057 | Val Acc: 0.5039
# Epoch 33/50 | Train Loss: 0.0695 | Val Loss: 1.9564 | Val Acc: 0.4857
# Epoch 34/50 | Train Loss: 0.0559 | Val Loss: 1.9927 | Val Acc: 0.4918
# Epoch 35/50 | Train Loss: 0.0443 | Val Loss: 2.0253 | Val Acc: 0.5022
# Epoch 36/50 | Train Loss: 0.0357 | Val Loss: 2.0693 | Val Acc: 0.4996
# Epoch 37/50 | Train Loss: 0.0296 | Val Loss: 2.1228 | Val Acc: 0.4987
# Epoch 38/50 | Train Loss: 0.0248 | Val Loss: 2.1724 | Val Acc: 0.4970
# Epoch 39/50 | Train Loss: 0.0204 | Val Loss: 2.2148 | Val Acc: 0.4961
# Epoch 40/50 | Train Loss: 0.0171 | Val Loss: 2.2513 | Val Acc: 0.4996
# Epoch 41/50 | Train Loss: 0.0149 | Val Loss: 2.2824 | Val Acc: 0.4978
# Epoch 42/50 | Train Loss: 0.0132 | Val Loss: 2.3126 | Val Acc: 0.5004
# Epoch 43/50 | Train Loss: 0.0116 | Val Loss: 2.3456 | Val Acc: 0.5030
# Epoch 44/50 | Train Loss: 0.0104 | Val Loss: 2.3778 | Val Acc: 0.5117
# Epoch 45/50 | Train Loss: 0.0096 | Val Loss: 2.4050 | Val Acc: 0.5134
# Epoch 46/50 | Train Loss: 0.0088 | Val Loss: 2.4297 | Val Acc: 0.5126
# Epoch 47/50 | Train Loss: 0.0081 | Val Loss: 2.4571 | Val Acc: 0.5108
# Epoch 48/50 | Train Loss: 0.0076 | Val Loss: 2.4878 | Val Acc: 0.5108
# Epoch 49/50 | Train Loss: 0.0073 | Val Loss: 2.5183 | Val Acc: 0.5082
# Epoch 50/50 | Train Loss: 0.0069 | Val Loss: 2.5468 | Val Acc: 0.5091

# %%
model.eval()
with torch.no_grad():
    test_outputs = model(X_val_tensor)
    test_preds = torch.argmax(test_outputs, dim=1)
    test_acc = (test_preds == y_val_tensor).float().mean()

print(f"✅ Test Accuracy: {test_acc:.4f}")
# Out:
# ✅ Test Accuracy: 0.5091

# %%
model.eval()
with torch.no_grad():
    test_outputs = model(X_test_tensor)
    test_preds = torch.argmax(test_outputs, dim=1)  # Indici delle classi predette

# Converti in etichette
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(fd[fd.columns[1]])  # Dove `fd.columns[1]` è la colonna dei generi

predicted_labels = label_encoder.inverse_transform(test_preds.numpy())

print(predicted_labels[:10])  # Stampa i primi 10 generi predetti
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 3
#       1 model.eval()
#       2 with torch.no_grad():
# ----> 3     test_outputs = model(X_test_tensor)
#       4     test_preds = torch.argmax(test_outputs, dim=1)  # Indici delle classi predette
#       6 # Converti in etichette
#
# NameError: name 'X_test_tensor' is not defined

# %%
print(X_test)
# Out:
# [[ 1.10836521  1.02699526  0.97695506 ...  1.54786814 -0.91114812
#   -0.45373743]
#  [-0.60175117  0.03544164  0.09765353 ... -0.39100477  0.1975857
#    0.84108338]
#  [ 0.82161626  0.70127059  0.76344635 ...  0.57843168 -0.5304248
#   -0.71449214]
#  ...
#  [ 1.30657146  1.21683709  1.37421557 ...  0.18184404 -0.3489863
#   -0.23177223]
#  [ 0.89676862  1.01796508  0.96958088 ...  0.95298668 -0.62091216
#   -0.65316508]
#  [-0.2647643  -0.52432301 -0.71748568 ... -2.44004093  4.0388302
#   -1.04743596]]

# %%
from DEF_batch import ExtractFeatures

pathIN = "TestTracks.csv"
pathOUT = "TestTracksFeatures.csv"
ExtractFeatures(pathIN,pathOUT)
# Out:
# 🎧 Inizio elaborazione delle canzoni
# TestTracks.csv TestTracksFeatures.csv Tracks/
# OK
# 🎧 Canzoni totali: 22
# ✅ Già elaborate: 21
# 🕐 Da elaborare: 1
#
# 🎵 Elaborazione: Pastello Bianco Pinguini Tattici Nucleari (Indie)
# Unexpected renderer encountered.
# Renderer name: dict_keys(['lockupViewModel'])
# Search term: Pastello Bianco Pinguini Tattici Nucleari
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Pastello Bianco Pinguini Tattici Nucleari
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Pastello Bianco Pinguini Tattici Nucleari
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# 🔍 YouTube URL trovato: https://youtube.com/watch?v=to8uZT8j8UI
# ⏱️ Durata video: 3 min 58 sec
# [youtube] Extracting URL: https://youtube.com/watch?v=to8uZT8j8UI
# [youtube] to8uZT8j8UI: Downloading webpage
# [youtube] to8uZT8j8UI: Downloading tv client config
# [youtube] to8uZT8j8UI: Downloading player 9a279502-main
# [youtube] to8uZT8j8UI: Downloading tv player API JSON
# [youtube] to8uZT8j8UI: Downloading ios player API JSON
# [youtube] to8uZT8j8UI: Downloading m3u8 information
# [info] to8uZT8j8UI: Downloading 1 format(s): 251
# [download] Destination: Tracks\tmp
# [download] 100% of    3.77MiB in 00:00:01 at 3.18MiB/s
# [ExtractAudio] Destination: Tracks\tmp.mp3
# Deleting original file Tracks\tmp (pass -k to keep)
# ✅ Estrazione dei 90 secondi centrali completata.
# ✅ Download completato con successo.
#
#
#
# 🎧 Caricamento audio da: Tracks//tmp90.mp3 di 90 sec
# 🎧 Audio caricato
#
# 🎧 Compattamento matrice (13, 8438) in 90 secondi
# (13, 90) (13, 90)
#
# 🎧 Compattamento matrice (12, 8438) in 90 secondi
# (12, 90) (12, 90)
#
# 🎧 Compattamento matrice (7, 8438) in 90 secondi
# (7, 90) (7, 90)
#
# 🎧 Compattamento matrice (1, 8438) in 90 secondi
# (1, 90) (1, 90)
# ✅ Estrazione delle caratteristiche completata.

# %%
import torch.nn.functional as F
songInfo = pd.read_csv(pathIN,encoding="utf-16")
test_df = pd.read_csv(pathOUT)
print(f"LEN:{len(test_df)}")
for r in range(len(test_df)):
    print(f"Riga {r}...")
    nuova_riga_df = test_df.iloc[r]  # Prendi la riga 4 (5a riga) del DataFrame
    #print(nuova_riga_df['id_track'])  # Prendi la prima riga del DataFrame
    new_feature_vector = preprocess_row(nuova_riga_df)  # stessa funzione usata prima
    new_feature_vector = scaler.transform([new_feature_vector])  # normalizzazione
    new_tensor = torch.tensor(new_feature_vector, dtype=torch.float32)

    model.eval()

    with torch.no_grad():
        output = model(new_tensor)
        probabilities = F.softmax(output, dim=1).numpy()[0]  # Applica softmax e ottieni l'array 1D

    print(f"Probabilità: {probabilities}")
    top3_indices = np.argsort(probabilities)[-3:][::-1]  # Ordina e prendi i primi 3 (in ordine decrescente)

    # Mappa gli indici ai nomi dei generi
    predicted_genres = label_encoder.inverse_transform(top3_indices)

    # Mostra i risultati con le probabilità
    print(f"🎧 Genere musicale predetto di: '{songInfo.iloc[r]['title']}' ID {nuova_riga_df['id_track']}: {predicted_genres}")    
    for genre, prob in zip(predicted_genres, probabilities[top3_indices]):
    #st.write(f"{genre}: {prob:.2%}")
        print(f"\t{genre}: {prob*100:.2f}%")
# Out:
# LEN:21
# Riga 0...
#
# Preprocessing riga 5840...
# Probabilità: [1.49266114e-02 3.19794461e-04 4.56345350e-01 1.22109028e-02
#  2.48157373e-03 6.43504923e-03 6.60131201e-02 1.37679090e-05
#  1.88662380e-03 2.94507574e-02 7.70735508e-03 9.85356164e-05
#  4.23640059e-03 1.63044572e-01 2.22442091e-01 2.67727824e-04
#  9.96192284e-06 2.99565261e-03 7.99126457e-03 1.03669496e-04
#  1.01924082e-03]
# 🎧 Genere musicale predetto di: 'Up From The Bottom Linkin Park' ID 0: ['Country' 'Punk' 'Pop']
# 	Country: 45.63%
# 	Punk: 22.24%
# 	Pop: 16.30%
# Riga 1...
#
# Preprocessing riga 5841...
# Probabilità: [7.1173755e-04 1.2481356e-05 2.1751912e-04 3.2958153e-01 3.8003037e-04
#  3.3849198e-04 2.8373498e-02 2.2796883e-04 4.5533932e-05 5.4212976e-02
#  1.4431088e-04 1.7324169e-03 3.0905632e-08 4.4426155e-01 3.6825935e-05
#  1.3762568e-01 9.5220930e-06 1.0605121e-03 6.6104496e-04 6.6740475e-05
#  2.9959509e-04]
# 🎧 Genere musicale predetto di: 'Beautiful People David Guetta' ID 1: ['Pop' 'Disco' 'R&B']
# 	Pop: 44.43%
# 	Disco: 32.96%
# 	R&B: 13.76%
# Riga 2...
#
# Preprocessing riga 5842...
# Probabilità: [9.6885860e-03 3.3894295e-04 2.1874068e-05 7.4783276e-04 1.6785615e-04
#  8.4035270e-07 1.1450743e-03 2.8101248e-03 7.9843408e-04 5.5572543e-02
#  1.5640272e-02 4.2365445e-03 8.8868124e-05 1.1582080e-01 2.9524054e-02
#  3.1918265e-02 4.3194191e-06 6.6580105e-01 4.7843382e-02 3.7083639e-05
#  1.7793132e-02]
# 🎧 Genere musicale predetto di: 'Runaway Kanye West' ID 2: ['Rock' 'Pop' 'Hip-Hop']
# 	Rock: 66.58%
# 	Pop: 11.58%
# 	Hip-Hop: 5.56%
# Riga 3...
#
# Preprocessing riga 5843...
# Probabilità: [2.1824222e-03 1.7969997e-04 3.1517674e-03 5.2852982e-08 4.7439499e-08
#  3.7731552e-05 3.9739403e-05 7.2109997e-06 1.0387865e-06 8.7746603e-06
#  3.1168014e-04 1.2826042e-06 9.8781151e-01 2.2245932e-07 3.0130583e-03
#  1.0771428e-04 2.4349290e-05 7.3641051e-05 2.9299693e-04 1.3252413e-05
#  2.7418358e-03]
# 🎧 Genere musicale predetto di: 'Nothing Else Matters Metallica' ID 3: ['Metal' 'Country' 'Punk']
# 	Metal: 98.78%
# 	Country: 0.32%
# 	Punk: 0.30%
# Riga 4...
#
# Preprocessing riga 5844...
# Probabilità: [1.3942479e-01 5.0739745e-06 5.6696933e-04 8.6711025e-06 1.5835732e-05
#  1.7600218e-05 7.0313849e-03 1.3253685e-04 5.6582827e-05 3.0245472e-05
#  4.2058792e-04 3.4019700e-04 2.7268394e-04 3.0759474e-02 2.7769249e-02
#  8.8360803e-06 2.8300866e-09 7.9235780e-01 1.7008610e-04 1.5397508e-04
#  4.5738256e-04]
# 🎧 Genere musicale predetto di: 'New Divide Linkin Park' ID 4: ['Rock' 'Blues' 'Pop']
# 	Rock: 79.24%
# 	Blues: 13.94%
# 	Pop: 3.08%
# Riga 5...
#
# Preprocessing riga 5845...
# Probabilità: [7.2090983e-02 6.0023382e-07 1.2411310e-03 2.7487398e-10 3.2484245e-08
#  1.4959022e-09 1.4131251e-07 8.7965724e-08 1.3739697e-08 2.6425024e-08
#  1.0767282e-06 4.5226085e-09 2.8038651e-04 4.6040621e-04 4.6841228e-01
#  4.9060834e-08 2.4693181e-10 4.5750609e-01 6.8068775e-06 1.9831219e-08
#  1.4240230e-08]
# 🎧 Genere musicale predetto di: 'The trooper Remaster Iron Maiden' ID 5: ['Punk' 'Rock' 'Blues']
# 	Punk: 46.84%
# 	Rock: 45.75%
# 	Blues: 7.21%
# Riga 6...
#
# Preprocessing riga 5846...
# Probabilità: [6.7094468e-09 6.2715952e-07 2.2246040e-06 3.9186111e-06 2.5404518e-06
#  3.2056607e-06 8.3783149e-08 4.9984478e-04 1.6274906e-09 8.6683531e-06
#  1.1601318e-07 1.1513930e-06 1.9089573e-08 4.4346231e-07 1.7937758e-07
#  9.9566311e-01 7.0816299e-07 3.9626480e-06 1.7256522e-06 3.6653323e-06
#  3.8037994e-03]
# 🎧 Genere musicale predetto di: 'I Luv Your Girl The-Dream' ID 3066: ['R&B' 'Trance' 'Folk']
# 	R&B: 99.57%
# 	Trance: 0.38%
# 	Folk: 0.05%
# Riga 7...
#
# Preprocessing riga 5847...
# Probabilità: [6.9330379e-02 9.2381239e-04 9.2768508e-01 9.1798174e-06 2.5893405e-08
#  2.3625786e-07 5.7109455e-06 1.2468351e-03 3.7280793e-07 4.8686990e-05
#  1.4882689e-07 9.3338795e-06 1.3200392e-07 1.2948290e-04 1.9518509e-04
#  1.0289789e-06 1.9922829e-04 1.0883362e-05 1.8759099e-04 1.0001412e-05
#  6.7840883e-06]
# 🎧 Genere musicale predetto di: ' Through the storm MAAPS' ID 6: ['Country' 'Blues' 'Folk']
# 	Country: 92.77%
# 	Blues: 6.93%
# 	Folk: 0.12%
# Riga 8...
#
# Preprocessing riga 5848...
# Probabilità: [1.2172774e-02 2.0667472e-05 6.6872315e-05 1.5527230e-03 3.8405966e-07
#  1.0838490e-09 9.6838048e-06 8.2234310e-06 6.5434381e-07 1.6801673e-03
#  3.0738021e-05 3.7329411e-04 8.7679535e-07 1.8717300e-03 3.9601667e-04
#  1.7964767e-04 2.7108624e-07 1.2889934e-02 9.6874410e-01 3.5607947e-08
#  1.1071539e-06]
# 🎧 Genere musicale predetto di: 'I want your love CHIC' ID 7: ['Soul' 'Rock' 'Blues']
# 	Soul: 96.87%
# 	Rock: 1.29%
# 	Blues: 1.22%
# Riga 9...
#
# Preprocessing riga 5849...
# Probabilità: [6.2980631e-05 9.3602971e-08 2.0164249e-03 6.0151231e-09 2.0541862e-07
#  5.8174191e-08 3.3119628e-07 1.5969498e-09 1.7745367e-07 9.6735562e-08
#  3.6323399e-08 4.7897941e-10 9.3477691e-05 5.0735698e-06 9.9779981e-01
#  2.8090170e-09 2.6632296e-09 1.9682460e-05 6.2707937e-07 8.7459370e-07
#  5.9695232e-08]
# 🎧 Genere musicale predetto di: 'In Too Deep Sum 41' ID 3240: ['Punk' 'Country' 'Metal']
# 	Punk: 99.78%
# 	Country: 0.20%
# 	Metal: 0.01%
# Riga 10...
#
# Preprocessing riga 5850...
# Probabilità: [6.98581716e-05 5.77430157e-08 6.63076207e-05 6.07837780e-09
#  3.38665359e-06 3.87862968e-07 2.33953160e-05 1.32085162e-10
#  2.67039081e-06 8.46690469e-08 7.97995483e-07 1.46893486e-09
#  1.16953044e-04 5.85222733e-04 9.98943508e-01 5.17912913e-09
#  1.59599382e-11 1.86967271e-04 3.77480944e-07 7.92132440e-08
#  8.84989326e-09]
# 🎧 Genere musicale predetto di: 'The Hell Song Sum 41' ID 3265: ['Punk' 'Pop' 'Rock']
# 	Punk: 99.89%
# 	Pop: 0.06%
# 	Rock: 0.02%
# Riga 11...
#
# Preprocessing riga 5851...
# Probabilità: [2.3379177e-07 3.7040936e-06 3.9096990e-06 1.2967603e-05 2.2193884e-02
#  1.1786930e-07 4.7500017e-03 4.3097181e-08 1.5437868e-06 1.8397778e-04
#  9.7183788e-01 4.5459915e-06 3.3259136e-07 6.6404783e-07 1.3059795e-04
#  2.6949499e-06 8.9745139e-05 9.2185346e-06 5.2698707e-04 2.4476054e-04
#  2.2097745e-06]
# 🎧 Genere musicale predetto di: 'Ease My Mind Chris Lake' ID 4813: ['House' 'Drum and Bass' 'Electronic']
# 	House: 97.18%
# 	Drum and Bass: 2.22%
# 	Electronic: 0.48%
# Riga 12...
#
# Preprocessing riga 5852...
# Probabilità: [6.3806679e-04 3.6714284e-04 5.4933476e-01 6.7571453e-03 1.1656064e-06
#  1.8280727e-04 4.1996283e-03 2.2669741e-05 1.0313330e-03 2.8412933e-03
#  1.0660476e-03 2.2884013e-04 1.4278522e-05 5.0998600e-03 2.8569277e-02
#  2.0045100e-03 2.4229288e-05 3.6004127e-05 3.8930678e-01 1.2558529e-03
#  7.0183328e-03]
# 🎧 Genere musicale predetto di: 'Falling for you' ID 8: ['Country' 'Soul' 'Punk']
# 	Country: 54.93%
# 	Soul: 38.93%
# 	Punk: 2.86%
# Riga 13...
#
# Preprocessing riga 5853...
# Probabilità: [6.85944190e-10 8.05133293e-10 8.31762298e-11 1.29858426e-08
#  9.99971986e-01 1.08861173e-06 3.92111588e-06 4.63095111e-13
#  2.60970569e-06 1.01662465e-07 1.14927852e-05 2.92764119e-10
#  9.56688131e-11 1.47365301e-06 3.02042650e-07 2.31727726e-09
#  1.55084516e-14 6.27769077e-06 5.45668843e-09 7.16656189e-07
#  1.57199975e-09]
# 🎧 Genere musicale predetto di: 'Say My Name - Sub Focus Remix Morgan Seatree' ID 5173: ['Drum and Bass' 'House' 'Rock']
# 	Drum and Bass: 100.00%
# 	House: 0.00%
# 	Rock: 0.00%
# Riga 14...
#
# Preprocessing riga 5854...
# Probabilità: [1.06346010e-06 1.97236217e-03 3.70047559e-07 1.43800194e-09
#  5.96338534e-10 1.12268566e-07 1.67086753e-07 1.61146618e-05
#  2.54131510e-06 1.29963793e-02 8.54950849e-06 1.40844004e-05
#  5.45301702e-07 7.45466577e-10 3.11252791e-07 6.05701018e-07
#  9.60728266e-06 1.18275716e-06 4.29526856e-03 1.29083998e-03
#  9.79389846e-01]
# 🎧 Genere musicale predetto di: 'breathe Amelie Lens' ID 9: ['Trance' 'Hip-Hop' 'Soul']
# 	Trance: 97.94%
# 	Hip-Hop: 1.30%
# 	Soul: 0.43%
# Riga 15...
#
# Preprocessing riga 5855...
# Probabilità: [2.1856426e-06 5.4117078e-07 7.2945585e-07 1.5699700e-04 6.7379999e-01
#  1.3997863e-01 1.7734827e-01 2.1813902e-10 1.8951473e-03 2.6167502e-06
#  1.6845504e-03 5.2912510e-06 2.1929492e-07 1.2571587e-04 3.6067871e-04
#  1.3555649e-06 1.2526969e-08 6.1931678e-07 1.3180119e-05 4.6226503e-03
#  5.2968880e-07]
# 🎧 Genere musicale predetto di: 'ciuri ciuri Angemi' ID 10: ['Drum and Bass' 'Electronic' 'Dubstep']
# 	Drum and Bass: 67.38%
# 	Electronic: 17.73%
# 	Dubstep: 14.00%
# Riga 16...
#
# Preprocessing riga 5856...
# Probabilità: [1.40073628e-03 3.51494295e-04 6.95550023e-03 1.04647856e-02
#  3.97368195e-03 5.36109030e-01 1.97216719e-01 1.51172353e-05
#  7.09396899e-02 4.64698067e-04 3.89801525e-03 3.28578230e-04
#  2.07011355e-03 4.55164234e-04 1.98250618e-02 1.00636692e-03
#  1.06645864e-03 2.23265975e-04 3.19539831e-04 1.23281494e-01
#  1.96344871e-02]
# 🎧 Genere musicale predetto di: 'Levels Angemi' ID 12: ['Dubstep' 'Electronic' 'Techno']
# 	Dubstep: 53.61%
# 	Electronic: 19.72%
# 	Techno: 12.33%
# Riga 17...
#
# Preprocessing riga 5857...
# Probabilità: [2.5617937e-03 5.3875749e-03 6.8653852e-04 2.5266697e-06 1.3072581e-04
#  1.1596768e-03 2.9564190e-01 1.0722726e-05 3.0210143e-04 3.1742585e-04
#  3.4947464e-01 7.4075484e-05 4.0799002e-03 1.0460773e-04 5.7145897e-02
#  2.1226485e-03 2.0859793e-06 2.8688362e-02 1.9062008e-01 1.1494043e-02
#  4.9992874e-02]
# 🎧 Genere musicale predetto di: 'Levels Avicii' ID 13: ['House' 'Electronic' 'Soul']
# 	House: 34.95%
# 	Electronic: 29.56%
# 	Soul: 19.06%
# Riga 18...
#
# Preprocessing riga 5858...
# Probabilità: [1.7725997e-05 2.0639577e-08 1.3215125e-08 7.0787673e-06 1.1044064e-04
#  3.9412786e-05 1.9056335e-02 2.8760607e-09 3.1263564e-05 9.4434068e-07
#  3.4535993e-04 1.5196026e-05 1.6164757e-08 2.3011363e-03 1.5444753e-03
#  2.2819746e-07 1.7314513e-09 1.2824705e-07 5.0874878e-08 9.7652495e-01
#  5.1253905e-06]
# 🎧 Genere musicale predetto di: 'Staring at the bottle Angemi' ID 14: ['Techno' 'Electronic' 'Pop']
# 	Techno: 97.65%
# 	Electronic: 1.91%
# 	Pop: 0.23%
# Riga 19...
#
# Preprocessing riga 5859...
# Probabilità: [1.61654389e-05 1.88807331e-04 1.67655708e-06 4.07673315e-06
#  1.70526132e-02 4.22625337e-03 7.94245183e-01 3.44253822e-05
#  6.73801537e-07 5.51430239e-05 1.08824037e-02 8.13686638e-05
#  9.09863375e-05 2.30304242e-04 7.52667431e-04 1.27860755e-02
#  9.98119720e-09 1.57343573e-03 1.43403068e-01 1.14907278e-02
#  2.88405316e-03]
# 🎧 Genere musicale predetto di: 'Monster Angemi' ID 15: ['Electronic' 'Soul' 'Drum and Bass']
# 	Electronic: 79.42%
# 	Soul: 14.34%
# 	Drum and Bass: 1.71%
# Riga 20...
#
# Preprocessing riga 5860...
# Probabilità: [1.5930877e-05 1.9783566e-02 3.3910175e-07 1.5134599e-06 2.4991903e-02
#  2.7270522e-04 2.2968703e-03 2.6810952e-04 2.1112483e-04 1.3314468e-02
#  4.8001818e-02 4.9583643e-04 2.9227146e-04 5.8322289e-06 2.3013170e-05
#  8.3176896e-04 2.2817423e-07 7.0985812e-03 1.7593260e-01 2.0000482e-02
#  6.8616110e-01]
# 🎧 Genere musicale predetto di: 'No es possible Angemi' ID 16: ['Trance' 'Soul' 'House']
# 	Trance: 68.62%
# 	Soul: 17.59%
# 	House: 4.80%

# %%
# torch.save(model, "intero_modello.pth")

# %%
torch.save(model.state_dict(), "modello_sicuro.pth")

# %%
model = MusicGenreClassifier()
model.load_state_dict(torch.load("modello_sicuro.pth"))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 model = torch.load("intero_modello.pth")
#       2 model.eval()
#
# File c:\Users\santi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)
#    1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    (...)
#    1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.MusicGenreClassifier was not an allowed global by default. Please use `torch.serialization.add_safe_globals([MusicGenreClassifier])` or the `torch.serialization.safe_globals([MusicGenreClassifier])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
test_df = pd.read_csv(pathOUT)
print(f"LEN:{len(test_df)}")
for r in range(len(test_df)):
    print(f"Riga {r}...")
    nuova_riga_df = test_df.iloc[r]  # Prendi la riga 4 (5a riga) del DataFrame
    #print(nuova_riga_df['id_track'])  # Prendi la prima riga del DataFrame
    new_feature_vector = preprocess_row(nuova_riga_df)  # stessa funzione usata prima
    new_feature_vector = scaler.transform([new_feature_vector])  # normalizzazione
    new_tensor = torch.tensor(new_feature_vector, dtype=torch.float32)

    model.eval()

    with torch.no_grad():
        output = model(new_tensor)
        prediction = torch.argmax(output, dim=1)

    predicted_genre = label_encoder.inverse_transform(prediction.numpy())[0]
    print(f"🎧 Genere musicale predetto di ID {nuova_riga_df['id_track']}: {predicted_genre}")
